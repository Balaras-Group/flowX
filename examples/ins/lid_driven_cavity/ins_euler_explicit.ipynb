# %%
# Sample API
import flowx
flowx.__version__
# Out:
# '0.1.dev'

# %%
# Define grid parameters
nx, ny = 40, 40
xmin, xmax = 0.0, 1.0
ymin, ymax = 0.0, 1.0

Re   = 100.0
dt   = 0.01
tmax = 10.

# Define cell-centered variable names
center_vars = ['pres', 'divv', 'asol', 'eror']
face_vars   = ['velc', 'hvar', 'asol', 'eror']

# Define boundary conditions for variable pressure and velocity [left, right, bottom, top]
bc_type_pres = {'pres': ['neumann', 'neumann', 'neumann', 'neumann']}
bc_val_pres  = {'pres': [0.0, 0.0, 0.0, 0.0]}

bc_type_u = {'velc': ['dirichlet', 'dirichlet', 'dirichlet', 'dirichlet']}
bc_val_u  = {'velc': [0.0, 0.0, 0.0, 1.0]}

bc_type_v = {'velc': ['dirichlet', 'dirichlet', 'dirichlet', 'dirichlet']}
bc_val_v  = {'velc': [0.0, 0.0, 0.0, 0.0]}

# Create the grid and data
gridc = flowx.Grid('cell-centered', center_vars,
                    nx, ny, xmin, xmax, ymin, ymax,
                    user_bc_type=bc_type_pres, user_bc_val=bc_val_pres)

gridx = flowx.Grid('x-face', face_vars,
                    nx, ny, xmin, xmax, ymin, ymax,
                    user_bc_type=bc_type_u, user_bc_val=bc_val_u)

gridy = flowx.Grid('y-face', face_vars,
                    nx, ny, xmin, xmax, ymin, ymax,
                    user_bc_type=bc_type_v, user_bc_val=bc_val_v)

scalars = flowx.Scalars(tmax=10.0, dt=0.01, Re=100.0)

# %%
ins_vars = ['velc', 'hvar', 'divv', 'pres']

while scalars.variable['time'] <= scalars.variable['tmax']:
    
    # Predictor Step
    flowx.ins.advance_euler(gridc, gridx, gridy, scalars, ins_vars, 'predictor')

    # Divergence Step
    flowx.ins.advance_euler(gridc, gridx, gridy, scalars, ins_vars, 'divergence')
    
    # Solve the pressure Poisson equation 
    scalars.stats['ites'], scalars.stats['res'] = flowx.poisson.solve_jacobi(gridc, 'pres', 'divv',
                                                                       maxiter=2000, tol=1e-9)
    
    # Corrector Step
    flowx.ins.advance_euler(gridc, gridx, gridy, scalars, ins_vars, 'corrector')
    
    # Display stats
    if scalars.variable['nstep'] % 10 == 0:
        flowx.io.display_stats(scalars)   

    scalars.advance()
# Out:
# ------------ Time = 0.0 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 1.659530608424263e-05
# Max, Min, U   : 2.0, -0.0636099254990361
# Max, Min, V   : 0.15977932482079868, -0.15977932482079868
# Max, Min, P   : 1.8058869165212974, -1.8058869165212974
# Max, Min, DIV : 0.0015938339462575613, -0.0015938339462575613
#
#
# ------------ Time = 0.09999999999999999 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 2.064619211142881e-07
# Max, Min, U   : 2.0, -0.1353479630140306
# Max, Min, V   : 0.30627573850763445, -0.3141633547834564
# Max, Min, P   : 1.1784419404705688, -0.8703514369192809
# Max, Min, DIV : 2.036048320164241e-05, -1.902794994101953e-05
#
#
# ------------ Time = 0.20000000000000004 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 6.963363741381347e-08
# Max, Min, U   : 2.0, -0.15408079650284984
# Max, Min, V   : 0.320051057133037, -0.3718028216546798
# Max, Min, P   : 1.1785149582352892, -0.7890500357071678
# Max, Min, DIV : 7.131945245930638e-06, -6.128175214282854e-06
#
#
# ------------ Time = 0.3000000000000001 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 3.788350278860708e-08
# Max, Min, U   : 2.0, -0.16485009742013315
# Max, Min, V   : 0.3301475726850164, -0.4053363943280285
# Max, Min, P   : 1.1917658812981629, -0.7559937361671847
# Max, Min, DIV : 4.010320239444809e-06, -3.473043887742384e-06
#
#
# ------------ Time = 0.4000000000000002 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 2.48293976424118e-08
# Max, Min, U   : 2.0, -0.17393799335491028
# Max, Min, V   : 0.3353191556889339, -0.4239701110908587
# Max, Min, P   : 1.2051222990500208, -0.7377210533703604
# Max, Min, DIV : 2.7035203942205044e-06, -2.3565547197443304e-06
#
#
# ------------ Time = 0.5000000000000002 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 1.793641195444765e-08
# Max, Min, U   : 2.0, -0.1814843672041565
# Max, Min, V   : 0.3383813799785567, -0.43556133078394454
# Max, Min, P   : 1.2169744500205988, -0.7261185040972784
# Max, Min, DIV : 2.000751083031105e-06, -1.7539755455901187e-06
#
#
# ------------ Time = 0.6000000000000003 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 1.3734553303434044e-08
# Max, Min, U   : 2.0, -0.18783571006490662
# Max, Min, V   : 0.34035350540295417, -0.443290603681952
# Max, Min, P   : 1.2272159221869352, -0.7181362841706004
# Max, Min, DIV : 1.5644927309210743e-06, -1.3788302939770312e-06
#
#
# ------------ Time = 0.7000000000000004 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 1.0924667660534378e-08
# Max, Min, U   : 2.0, -0.19289605762678305
# Max, Min, V   : 0.3416960175811894, -0.4486940691353116
# Max, Min, P   : 1.2360217809744307, -0.7123488936917536
# Max, Min, DIV : 1.267457898634916e-06, -1.1228081591436578e-06
#
#
# ------------ Time = 0.8000000000000005 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 8.92229115040531e-09
# Max, Min, U   : 2.0, -0.19878844771733487
# Max, Min, V   : 0.3426475031711894, -0.4578728171765182
# Max, Min, P   : 1.2436061749261254, -0.7079943740069814
# Max, Min, DIV : 1.0519727648983235e-06, -9.367243019094574e-07
#
#
# ------------ Time = 0.9000000000000006 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 7.429031716840636e-09
# Max, Min, U   : 2.0, -0.2039563295400553
# Max, Min, V   : 0.34334346331686344, -0.4669394424381603
# Max, Min, P   : 1.250165906865611, -0.7046262350746647
# Max, Min, DIV : 8.883984303764692e-07, -7.952513587409452e-07
#
#
# ------------ Time = 1.0000000000000007 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 6.277554254242463e-09
# Max, Min, U   : 2.0, -0.20773914304052515
# Max, Min, V   : 0.34386599898024844, -0.47408991745796275
# Max, Min, P   : 1.2558689542835049, -0.7019646339051868
# Max, Min, DIV : 7.600197928780972e-07, -6.840777975471949e-07
#
#
# ------------ Time = 1.1000000000000008 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 5.36690457923243e-09
# Max, Min, U   : 2.0, -0.21184946089885576
# Max, Min, V   : 0.3442672725994592, -0.47980815462312537
# Max, Min, P   : 1.260855020257868, -0.6998248974887874
# Max, Min, DIV : 6.567070354179805e-07, -5.945128367275399e-07
#
#
# ------------ Time = 1.2000000000000008 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 4.632502356623345e-09
# Max, Min, U   : 2.0, -0.21465534298212446
# Max, Min, V   : 0.3445816397057795, -0.48443887624927245
# Max, Min, P   : 1.2652391412950053, -0.6980800874353781
# Max, Min, DIV : 5.719572051532396e-07, -5.209654222418803e-07
#
#
# ------------ Time = 1.300000000000001 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 4.031015915572391e-09
# Max, Min, U   : 2.0, -0.21730515631427136
# Max, Min, V   : 0.344832375953065, -0.4882322360150945
# Max, Min, P   : 1.2691157130411375, -0.6966400295902646
# Max, Min, DIV : 5.013934973874257e-07, -4.5966417564673526e-07
#
#
# ------------ Time = 1.400000000000001 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 3.532206924118837e-09
# Max, Min, U   : 2.0, -0.2198799366413019
# Max, Min, V   : 0.3450356178764043, -0.49137259656864696
# Max, Min, P   : 1.2725621664255475, -0.6954389149835806
# Max, Min, DIV : 4.4195072490538223e-07, -4.0796229795140443e-07
#
#
# ------------ Time = 1.500000000000001 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 3.114277176597411e-09
# Max, Min, U   : 2.0, -0.22165864620499648
# Max, Min, V   : 0.34520277450051534, -0.4939976782392497
# Max, Min, P   : 1.2756421122160029, -0.6944276338768263
# Max, Min, DIV : 3.9140816809890566e-07, -3.6393858838970443e-07
#
#
# ------------ Time = 1.6000000000000012 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 2.761081533945261e-09
# Max, Min, U   : 2.0, -0.2241499961268597
# Max, Min, V   : 0.34534205524775685, -0.4962116263468129
# Max, Min, P   : 1.2784079557630572, -0.693568853261331
# Max, Min, DIV : 3.481088821644107e-07, -3.2615759610384737e-07
#
#
# ------------ Time = 1.7000000000000013 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 2.460387001612617e-09
# Max, Min, U   : 2.0, -0.22578298523039628
# Max, Min, V   : 0.34545946468135236, -0.49809410713352315
# Max, Min, P   : 1.2809030377147517, -0.6928337508366805
# Max, Min, DIV : 3.1078470819068116e-07, -2.935197497117535e-07
#
#
# ------------ Time = 1.8000000000000014 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 2.202744944040517e-09
# Max, Min, U   : 2.0, -0.2267252047414178
# Max, Min, V   : 0.34555946400837484, -0.49970673725375164
# Max, Min, P   : 1.2831633686261248, -0.6921997850138092
# Max, Min, DIV : 2.784434673941405e-07, -2.651645998781593e-07
#
#
# ------------ Time = 1.9000000000000015 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 1.980737072950545e-09
# Max, Min, U   : 2.0, -0.22796065439601698
# Max, Min, V   : 0.34564541840287794, -0.5010976835926356
# Max, Min, P   : 1.2852190240877985, -0.6916491332869897
# Max, Min, DIV : 2.5029410544163966e-07, -2.404065571441627e-07
#
#
# ------------ Time = 2.0000000000000013 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 1.7884572663052757e-09
# Max, Min, U   : 2.0, -0.22920315320070783
# Max, Min, V   : 0.3457199037156403, -0.5023049871330189
# Max, Min, P   : 1.2870952611561222, -0.6911675739057308
# Max, Min, DIV : 2.2569601654254257e-07, -2.1869109914206958e-07
#
#
# ------------ Time = 2.099999999999999 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 1.6211466791455963e-09
# Max, Min, U   : 2.0, -0.22999745778673153
# Max, Min, V   : 0.3457849193864586, -0.5033589865476802
# Max, Min, P   : 1.2888134093455659, -0.6907436690161266
# Max, Min, DIV : 2.0412366907862634e-07, -1.9956418548195895e-07
#
#
# ------------ Time = 2.199999999999997 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 1.4749311576739336e-09
# Max, Min, U   : 2.0, -0.23042888982069643
# Max, Min, V   : 0.345842038013429, -0.5042841010240164
# Max, Min, P   : 1.290391581420455, -0.6903681575197838
# Max, Min, DIV : 1.8514140087688702e-07, -1.8265037103832107e-07
# ------------ Time = 2.299999999999995 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 1.3466285347661043e-09
# Max, Min, U   : 2.0, -0.23138473707492563
# Max, Min, V   : 0.34589251170171614, -0.5054388531804402
# Max, Min, P   : 1.2918452414010622, -0.6900334968492565
# Max, Min, DIV : 1.6838506589067492e-07, -1.6763675892176796e-07
#
#
# ------------ Time = 2.399999999999993 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 1.2336046809737863e-09
# Max, Min, U   : 2.0, -0.23230424386614743
# Max, Min, V   : 0.3459373486355113, -0.5065731899526078
# Max, Min, P   : 1.2931876600475576, -0.6897335124635396
# Max, Min, DIV : 1.5354828164504397e-07, -1.5426095069598703e-07
#
#
# ------------ Time = 2.4999999999999907 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 1.1336642808297602e-09
# Max, Min, U   : 2.0, -0.23296913127681557
# Max, Min, V   : 0.34597736893112635, -0.5075870871256203
# Max, Min, P   : 1.2944302818714242, -0.6894631265711632
# Max, Min, DIV : 1.40371874124412e-07, -1.423017946863142e-07
#
#
# ------------ Time = 2.5999999999999885 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 1.0449668069281256e-09
# Max, Min, U   : 2.0, -0.23342410126629695
# Max, Min, V   : 0.3460132459198468, -0.5084967919093514
# Max, Min, P   : 1.2955830225391742, -0.6892181459989455
# Max, Min, DIV : 1.2863573672916573e-07, -1.315721365612206e-07
#
#
# ------------ Time = 2.6999999999999864 ---------------
# Number of poisson iterations    : 1979
# Final poisson residual : 9.993381310302993e-10
# Max, Min, U   : 2.0, -0.23370688348524554
# Max, Min, V   : 0.3460455371299995, -0.5093159495979188
# Max, Min, P   : 1.2966545218532595, -0.6889950937872797
# Max, Min, DIV : 1.2216587563784742e-07, -1.26191487775755e-07
#
#
# ------------ Time = 2.7999999999999843 ---------------
# Number of poisson iterations    : 1932
# Final poisson residual : 9.996774730752608e-10
# Max, Min, U   : 2.0, -0.23384919444539126
# Max, Min, V   : 0.34607470749977, -0.5100560768698541
# Max, Min, P   : 1.2976523010664733, -0.6887910799433274
# Max, Min, DIV : 1.2114442426991445e-07, -1.2665731100513708e-07
#
#
# ------------ Time = 2.899999999999982 ---------------
# Number of poisson iterations    : 1887
# Final poisson residual : 9.995460440227051e-10
# Max, Min, U   : 2.0, -0.23425814488524288
# Max, Min, V   : 0.34610114769602074, -0.5107269392474874
# Max, Min, P   : 1.2985829881375452, -0.6886036893145322
# Max, Min, DIV : 1.1992861459475535e-07, -1.2705920701423096e-07
#
#
# ------------ Time = 2.99999999999998 ---------------
# Number of poisson iterations    : 1844
# Final poisson residual : 9.989907111505689e-10
# Max, Min, U   : 2.0, -0.23474947684553574
# Max, Min, V   : 0.34612518797769565, -0.5113368541857717
# Max, Min, P   : 1.2994524132543606, -0.6884308994364389
# Max, Min, DIV : 1.1853607517764431e-07, -1.2740096269874684e-07
#
#
# ------------ Time = 3.099999999999978 ---------------
# Number of poisson iterations    : 1802
# Final poisson residual : 9.9921601271525e-10
# Max, Min, U   : 2.0, -0.23512627507324219
# Max, Min, V   : 0.3461471091578277, -0.5118929345124211
# Max, Min, P   : 1.3002657376508584, -0.6882710088532659
# Max, Min, DIV : 1.171113375164623e-07, -1.2784385874974394e-07
#
#
# ------------ Time = 3.1999999999999758 ---------------
# Number of poisson iterations    : 1762
# Final poisson residual : 9.985430040536378e-10
# Max, Min, U   : 2.0, -0.23540702457204027
# Max, Min, V   : 0.34616715129892395, -0.5124012867777187
# Max, Min, P   : 1.3010275386056158, -0.6881225824890078
# Max, Min, DIV : 1.1547580314186234e-07, -1.281659662085051e-07
#
#
# ------------ Time = 3.2999999999999736 ---------------
# Number of poisson iterations    : 1723
# Final poisson residual : 9.985435313233026e-10
# Max, Min, U   : 2.0, -0.23560747321845255
# Max, Min, V   : 0.3461855206827347, -0.5128671734938552
# Max, Min, P   : 1.3017418951540969, -0.6879844046207197
# Max, Min, DIV : 1.1381531273002565e-07, -1.2857732247179357e-07
#
#
# ------------ Time = 3.3999999999999715 ---------------
# Number of poisson iterations    : 1685
# Final poisson residual : 9.988409615451446e-10
# Max, Min, U   : 2.0, -0.23574101710220952
# Max, Min, V   : 0.34620239541878395, -0.5132951463635586
# Max, Min, P   : 1.3024124606104115, -0.6878554392506674
# Max, Min, DIV : 1.1209226968844632e-07, -1.2903398851141223e-07
#
#
# ------------ Time = 3.4999999999999694 ---------------
# Number of poisson iterations    : 1648
# Final poisson residual : 9.991456637970724e-10
# Max, Min, U   : 2.0, -0.2358190371718487
# Max, Min, V   : 0.34621792997261924, -0.5136891563483841
# Max, Min, P   : 1.3030425105786045, -0.6877348015281243
# Max, Min, DIV : 1.1028121171818839e-07, -1.2950270781436624e-07
#
#
# ------------ Time = 3.5999999999999672 ---------------
# Number of poisson iterations    : 1612
# Final poisson residual : 9.997730231593218e-10
# Max, Min, U   : 2.0, -0.23585119115072362
# Max, Min, V   : 0.34623225888399156, -0.5140526449152278
# Max, Min, P   : 1.3036349929560358, -0.6876217323617047
# Max, Min, DIV : 1.0842986419845602e-07, -1.3002376253240175e-07
#
#
# ------------ Time = 3.699999999999965 ---------------
# Number of poisson iterations    : 1578
# Final poisson residual : 9.988804606156734e-10
# Max, Min, U   : 2.0, -0.2359825057955507
# Max, Min, V   : 0.346245499814523, -0.514388619976015
# Max, Min, P   : 1.304192574739449, -0.6875155752397284
# Max, Min, DIV : 1.0637137570768118e-07, -1.3034158939488616e-07
#
#
# ------------ Time = 3.799999999999963 ---------------
# Number of poisson iterations    : 1544
# Final poisson residual : 9.99260728004882e-10
# Max, Min, U   : 2.0, -0.23630701395922785
# Max, Min, V   : 0.3462577560770707, -0.5146997194185252
# Max, Min, P   : 1.3047176764866886, -0.6874157586116715
# Max, Min, DIV : 1.0437171304999993e-07, -1.308589188532376e-07
#
#
# ------------ Time = 3.899999999999961 ---------------
# Number of poisson iterations    : 1511
# Final poisson residual : 9.992255692633506e-10
# Max, Min, U   : 2.0, -0.2365847933872599
# Max, Min, V   : 0.3462691187001119, -0.5149882642085905
# Max, Min, P   : 1.305212496076, -0.6873217847048926
# Max, Min, DIV : 1.0227898528114565e-07, -1.313406083275695e-07
#
#
# ------------ Time = 3.9999999999999587 ---------------
# Number of poisson iterations    : 1479
# Final poisson residual : 9.987656001331212e-10
# Max, Min, U   : 2.0, -0.23682217646681003
# Max, Min, V   : 0.3462796681922788, -0.5152563031753624
# Max, Min, P   : 1.3056790413397785, -0.6872332147684508
# Max, Min, DIV : 1.0010436390928135e-07, -1.3178530163969124e-07
#
#
# ------------ Time = 4.099999999999957 ---------------
# Number of poisson iterations    : 1447
# Final poisson residual : 9.995710224488931e-10
# Max, Min, U   : 2.0, -0.23702464278214427
# Max, Min, V   : 0.3462894759943961, -0.5155056507265606
# Max, Min, P   : 1.3061191482798067, -0.6871496609276432
# Max, Min, DIV : 9.799456535120044e-08, -1.324401509741717e-07
#
#
# ------------ Time = 4.199999999999955 ---------------
# Number of poisson iterations    : 1416
# Final poisson residual : 9.996540512165724e-10
# Max, Min, U   : 2.0, -0.2371969344019324
# Max, Min, V   : 0.3462986057000971, -0.5157379186854268
# Max, Min, P   : 1.3065345022563248, -0.6870707774022222
# Max, Min, DIV : 9.578113768782259e-08, -1.330244651723267e-07
#
#
# ------------ Time = 4.299999999999953 ---------------
# Number of poisson iterations    : 1386
# Final poisson residual : 9.989066611866826e-10
# Max, Min, U   : 2.0, -0.2373431558135601
# Max, Min, V   : 0.34630711410503007, -0.5159545433855293
# Max, Min, P   : 1.3069266536328545, -0.6869962542446939
# Max, Min, DIV : 9.3465207129384e-08, -1.3352261606092153e-07
#
#
# ------------ Time = 4.399999999999951 ---------------
# Number of poisson iterations    : 1356
# Final poisson residual : 9.9912728545563e-10
# Max, Min, U   : 2.0, -0.23746686031469022
# Max, Min, V   : 0.34631505208519936, -0.5161568086566585
# Max, Min, P   : 1.307297032514893, -0.6869258117400582
# Max, Min, DIV : 9.118453014878014e-08, -1.3420213381505272e-07
#
#
# ------------ Time = 4.4999999999999485 ---------------
# Number of poisson iterations    : 1326
# Final poisson residual : 9.998331109550657e-10
# Max, Min, U   : 2.0, -0.23757112464295851
# Max, Min, V   : 0.34632246533590283, -0.5163458653683386
# Max, Min, P   : 1.3076469619218831, -0.6868591951496678
# Max, Min, DIV : 8.887645286392853e-08, -1.350108563206824e-07
# ------------ Time = 4.599999999999946 ---------------
# Number of poisson iterations    : 1297
# Final poisson residual : 9.999170413332975e-10
# Max, Min, U   : 2.0, -0.2376586134887429
# Max, Min, V   : 0.34632939501858684, -0.5165227482010764
# Max, Min, P   : 1.3079776648623411, -0.6867961743417311
# Max, Min, DIV : 8.649898930457312e-08, -1.3575906414407118e-07
#
#
# ------------ Time = 4.699999999999944 ---------------
# Number of poisson iterations    : 1269
# Final poisson residual : 9.992783944922729e-10
# Max, Min, U   : 2.0, -0.23773163518635815
# Max, Min, V   : 0.3463358783062283, -0.5166883899818739
# Max, Min, P   : 1.3082902786756703, -0.6867365366594382
# Max, Min, DIV : 8.40607423668871e-08, -1.364294450125099e-07
#
#
# ------------ Time = 4.799999999999942 ---------------
# Number of poisson iterations    : 1241
# Final poisson residual : 9.99009617391765e-10
# Max, Min, U   : 2.0, -0.23779218978512745
# Max, Min, V   : 0.34634194885866804, -0.516843633998875
# Max, Min, P   : 1.3085858628461966, -0.6866800842355913
# Max, Min, DIV : 8.233557924341994e-08, -1.372161482268014e-07
#
#
# ------------ Time = 4.89999999999994 ---------------
# Number of poisson iterations    : 1213
# Final poisson residual : 9.99553472711291e-10
# Max, Min, U   : 2.0, -0.23784201053602272
# Max, Min, V   : 0.34634763722300643, -0.5169892445892837
# Max, Min, P   : 1.3088654019097656, -0.6866266363595603
# Max, Min, DIV : 8.160561506403985e-08, -1.3817674222264126e-07
#
#
# ------------ Time = 4.999999999999938 ---------------
# Number of poisson iterations    : 1186
# Final poisson residual : 9.986289654717077e-10
# Max, Min, U   : 2.0, -0.23788259970285264
# Max, Min, V   : 0.3463529711800844, -0.5171259162618269
# Max, Min, P   : 1.3091298149473578, -0.6865760245739014
# Max, Min, DIV : 8.138924076361853e-08, -1.3896381977334532e-07
#
#
# ------------ Time = 5.099999999999936 ---------------
# Number of poisson iterations    : 1159
# Final poisson residual : 9.985552410788197e-10
# Max, Min, U   : 2.0, -0.2379152595404054
# Max, Min, V   : 0.34635797606925645, -0.5172542816661467
# Max, Min, P   : 1.3093799628399996, -0.6865280906929241
# Max, Min, DIV : 8.163934150928753e-08, -1.3993076931114595e-07
#
#
# ------------ Time = 5.199999999999934 ---------------
# Number of poisson iterations    : 1132
# Final poisson residual : 9.99148759329723e-10
# Max, Min, U   : 2.0, -0.23794111896806322
# Max, Min, V   : 0.34636267503130863, -0.5173749183964691
# Max, Min, P   : 1.3096166493147536, -0.686482687860254
# Max, Min, DIV : 8.219647146257003e-08, -1.4105950154989777e-07
#
#
# ------------ Time = 5.299999999999931 ---------------
# Number of poisson iterations    : 1106
# Final poisson residual : 9.989629134639588e-10
# Max, Min, U   : 2.0, -0.2379611566661296
# Max, Min, V   : 0.3463670892511763, -0.5174883549701871
# Max, Min, P   : 1.309840627702922, -0.6864396788834447
# Max, Min, DIV : 8.28243809647411e-08, -1.420897415898778e-07
#
#
# ------------ Time = 5.399999999999929 ---------------
# Number of poisson iterations    : 1080
# Final poisson residual : 9.989675669156115e-10
# Max, Min, U   : 2.0, -0.23802083753618478
# Max, Min, V   : 0.3463712381582802, -0.5175950760370376
# Max, Min, P   : 1.310052605883778, -0.686398932420923
# Max, Min, DIV : 8.35130127829764e-08, -1.4322197545687046e-07
#
#
# ------------ Time = 5.499999999999927 ---------------
# Number of poisson iterations    : 1054
# Final poisson residual : 9.990879954069383e-10
# Max, Min, U   : 2.0, -0.23814589796527433
# Max, Min, V   : 0.34637513960399463, -0.5176955269069901
# Max, Min, P   : 1.3102532476247717, -0.6863603264592497
# Max, Min, DIV : 8.421281577630779e-08, -1.4445029863831976e-07
#
#
# ------------ Time = 5.599999999999925 ---------------
# Number of poisson iterations    : 1029
# Final poisson residual : 9.988999646910721e-10
# Max, Min, U   : 2.0, -0.23826092613547314
# Max, Min, V   : 0.3463788100220585, -0.5177901175409781
# Max, Min, P   : 1.3104431756707697, -0.6863237487300226
# Max, Min, DIV : 8.483118751900776e-08, -1.4562636201087553e-07
#
#
# ------------ Time = 5.699999999999923 ---------------
# Number of poisson iterations    : 1004
# Final poisson residual : 9.989742089257137e-10
# Max, Min, U   : 2.0, -0.23836685951099468
# Max, Min, V   : 0.34638226455878357, -0.5178792260204099
# Max, Min, P   : 1.3106229781132472, -0.6862890881737942
# Max, Min, DIV : 8.541121010452457e-08, -1.4691232563899398e-07
#
#
# ------------ Time = 5.799999999999921 ---------------
# Number of poisson iterations    : 979
# Final poisson residual : 9.99324976087911e-10
# Max, Min, U   : 2.0, -0.23846453620921818
# Max, Min, V   : 0.34638551719970667, -0.5179632016386378
# Max, Min, P   : 1.3107932072682378, -0.6862562424789205
# Max, Min, DIV : 8.592710265542536e-08, -1.4831149831515122e-07
#
#
# ------------ Time = 5.899999999999919 ---------------
# Number of poisson iterations    : 955
# Final poisson residual : 9.993220157386822e-10
# Max, Min, U   : 2.0, -0.23855470652420283
# Max, Min, V   : 0.34638858087946883, -0.5180423676181363
# Max, Min, P   : 1.3109543824919847, -0.6862251177302763
# Max, Min, DIV : 8.632038994704772e-08, -1.4963857661223073e-07
#
#
# ------------ Time = 5.9999999999999165 ---------------
# Number of poisson iterations    : 931
# Final poisson residual : 9.99624533047497e-10
# Max, Min, U   : 2.0, -0.23863804302527827
# Max, Min, V   : 0.3463914675710027, -0.5181170234883599
# Max, Min, P   : 1.3111069951846792, -0.6861956199008098
# Max, Min, DIV : 8.664845985162373e-08, -1.510764529645027e-07
#
#
# ------------ Time = 6.099999999999914 ---------------
# Number of poisson iterations    : 908
# Final poisson residual : 9.98471245364775e-10
# Max, Min, U   : 2.0, -0.23871514942108016
# Max, Min, V   : 0.34639418837625935, -0.5181874472350305
# Max, Min, P   : 1.3112515069840283, -0.6861676640458336
# Max, Min, DIV : 8.676032647869647e-08, -1.5227880949784944e-07
#
#
# ------------ Time = 6.199999999999912 ---------------
# Number of poisson iterations    : 884
# Final poisson residual : 9.99906956043943e-10
# Max, Min, U   : 2.0, -0.23878656836294912
# Max, Min, V   : 0.3463967536038082, -0.5182538972006024
# Max, Min, P   : 1.3113883556505541, -0.6861411663858609
# Max, Min, DIV : 8.699018583246954e-08, -1.5400504560980285e-07
#
#
# ------------ Time = 6.29999999999991 ---------------
# Number of poisson iterations    : 862
# Final poisson residual : 9.990125405168295e-10
# Max, Min, U   : 2.0, -0.2388527882546743
# Max, Min, V   : 0.34639917283564137, -0.5183166137585233
# Max, Min, P   : 1.3115179513070452, -0.6861160538397154
# Max, Min, DIV : 8.693559316874655e-08, -1.5524309067167091e-07
#
#
# ------------ Time = 6.399999999999908 ---------------
# Number of poisson iterations    : 839
# Final poisson residual : 9.999638865640449e-10
# Max, Min, U   : 2.0, -0.23891424929814692
# Max, Min, V   : 0.34640145497715563, -0.5183758208105933
# Max, Min, P   : 1.3116406842923323, -0.686092248513444
# Max, Min, DIV : 8.696123443563408e-08, -1.569086991214455e-07
#
#
# ------------ Time = 6.499999999999906 ---------------
# Number of poisson iterations    : 818
# Final poisson residual : 9.984854896632522e-10
# Max, Min, U   : 2.0, -0.2389713487838282
# Max, Min, V   : 0.34640360833790984, -0.5184317271921534
# Max, Min, P   : 1.3117569204754915, -0.6860696862935188
# Max, Min, DIV : 8.671894108358558e-08, -1.5804050818978704e-07
#
#
# ------------ Time = 6.599999999999904 ---------------
# Number of poisson iterations    : 796
# Final poisson residual : 9.994321203394268e-10
# Max, Min, U   : 2.0, -0.23902444576095747
# Max, Min, V   : 0.3464056406500118, -0.5184845278205554
# Max, Min, P   : 1.3118670081360293, -0.6860482972275591
# Max, Min, DIV : 8.656680067220535e-08, -1.596602129862873e-07
#
#
# ------------ Time = 6.699999999999902 ---------------
# Number of poisson iterations    : 775
# Final poisson residual : 9.995455638085538e-10
# Max, Min, U   : 2.0, -0.2390738651573549
# Max, Min, V   : 0.34640755913964816, -0.5185344048493721
# Max, Min, P   : 1.3119712749319312, -0.6860280222839455
# Max, Min, DIV : 8.630425513134199e-08, -1.6107479021551172e-07
#
#
# ------------ Time = 6.7999999999998995 ---------------
# Number of poisson iterations    : 755
# Final poisson residual : 9.987941774217585e-10
# Max, Min, U   : 2.0, -0.23911990141934666
# Max, Min, V   : 0.3464093705526513, -0.5185815286259075
# Max, Min, P   : 1.3120700312901366, -0.6860088027547951
# Max, Min, DIV : 8.593244810173317e-08, -1.6226621119127746e-07
# ------------ Time = 6.899999999999897 ---------------
# Number of poisson iterations    : 735
# Final poisson residual : 9.986558978713984e-10
# Max, Min, U   : 2.0, -0.2391628217265446
# Max, Min, V   : 0.3464110811885108, -0.5186260585818571
# Max, Min, P   : 1.3121635698036012, -0.6859905820734147
# Max, Min, DIV : 8.552079777679467e-08, -1.63547071133259e-07
#
#
# ------------ Time = 6.999999999999895 ---------------
# Number of poisson iterations    : 715
# Final poisson residual : 9.997740515250948e-10
# Max, Min, U   : 2.0, -0.23920286883871178
# Max, Min, V   : 0.3464126969465027, -0.5186681440711229
# Max, Min, P   : 1.3122521680787653, -0.6859733084560363
# Max, Min, DIV : 8.513521548847436e-08, -1.6500554671618553e-07
#
#
# ------------ Time = 7.099999999999893 ---------------
# Number of poisson iterations    : 696
# Final poisson residual : 9.994812292334346e-10
# Max, Min, U   : 2.0, -0.23924026361793338
# Max, Min, V   : 0.34641422334760863, -0.5187079250932255
# Max, Min, P   : 1.3123360884450923, -0.6859569323202215
# Max, Min, DIV : 8.464327683199713e-08, -1.6612510509578238e-07
#
#
# ------------ Time = 7.199999999999891 ---------------
# Number of poisson iterations    : 677
# Final poisson residual : 9.995435163695874e-10
# Max, Min, U   : 2.0, -0.2392752072594959
# Max, Min, V   : 0.3464156655575095, -0.51874553295194
# Max, Min, P   : 1.312415578301299, -0.6859414063982113
# Max, Min, DIV : 8.408927304470737e-08, -1.672689655496211e-07
#
#
# ------------ Time = 7.299999999999889 ---------------
# Number of poisson iterations    : 659
# Final poisson residual : 9.998373769048207e-10
# Max, Min, U   : 2.0, -0.23930788329919406
# Max, Min, V   : 0.34641702843720124, -0.5187810909273988
# Max, Min, P   : 1.3124908748464195, -0.6859266871673579
# Max, Min, DIV : 8.35235489105024e-08, -1.6830135665061446e-07
#
#
# ------------ Time = 7.399999999999887 ---------------
# Number of poisson iterations    : 642
# Final poisson residual : 9.984284402985943e-10
# Max, Min, U   : 2.0, -0.23933845934145906
# Max, Min, V   : 0.34641831652542726, -0.5188147147558029
# Max, Min, P   : 1.3125621980746158, -0.6859127328209238
# Max, Min, DIV : 8.278445723375327e-08, -1.6891515189658077e-07
#
#
# ------------ Time = 7.4999999999998845 ---------------
# Number of poisson iterations    : 624
# Final poisson residual : 9.999023575122992e-10
# Max, Min, U   : 2.0, -0.23936708864538164
# Max, Min, V   : 0.3464195340736375, -0.5188465131603583
# Max, Min, P   : 1.312629758727877, -0.6858995004534106
# Max, Min, DIV : 8.22368299568943e-08, -1.7001924630666299e-07
#
#
# ------------ Time = 7.599999999999882 ---------------
# Number of poisson iterations    : 608
# Final poisson residual : 9.981370901791984e-10
# Max, Min, U   : 2.0, -0.23939391156042486
# Max, Min, V   : 0.34642068511282087, -0.5188765884457058
# Max, Min, P   : 1.3126937564455945, -0.6858869568288789
# Max, Min, DIV : 8.145345914423174e-08, -1.7035543409173876e-07
#
#
# ------------ Time = 7.69999999999988 ---------------
# Number of poisson iterations    : 591
# Final poisson residual : 9.993206813732254e-10
# Max, Min, U   : 2.0, -0.23941905669721814
# Max, Min, V   : 0.3464217733790259, -0.5189050367136159
# Max, Min, P   : 1.3127543780815003, -0.6858750629461974
# Max, Min, DIV : 8.077330693190277e-08, -1.7115482917051672e-07
#
#
# ------------ Time = 7.799999999999878 ---------------
# Number of poisson iterations    : 575
# Final poisson residual : 9.996072580258557e-10
# Max, Min, U   : 2.0, -0.2394426421276329
# Max, Min, V   : 0.3464228024263192, -0.5189319484920385
# Max, Min, P   : 1.3128118042911452, -0.6858637861718879
# Max, Min, DIV : 8.019521435809196e-08, -1.7164861960614064e-07
#
#
# ------------ Time = 7.899999999999876 ---------------
# Number of poisson iterations    : 560
# Final poisson residual : 9.986235164553145e-10
# Max, Min, U   : 2.0, -0.2394647763244091
# Max, Min, V   : 0.3464237755788439, -0.5189574089566594
# Max, Min, P   : 1.3128662035512624, -0.68585309474425
# Max, Min, DIV : 7.993653350357732e-08, -1.7178807393703616e-07
#
#
# ------------ Time = 7.999999999999874 ---------------
# Number of poisson iterations    : 545
# Final poisson residual : 9.982074500147226e-10
# Max, Min, U   : 2.0, -0.23948555905873173
# Max, Min, V   : 0.34642469595291814, -0.5189814982938253
# Max, Min, P   : 1.3129177346850833, -0.6858429575642868
# Max, Min, DIV : 8.010590607510082e-08, -1.719162465883481e-07
#
#
# ------------ Time = 8.099999999999872 ---------------
# Number of poisson iterations    : 530
# Final poisson residual : 9.981854368673496e-10
# Max, Min, U   : 2.0, -0.23950508221955122
# Max, Min, V   : 0.3464255664893985, -0.5190042920620921
# Max, Min, P   : 1.3129665481417125, -0.6858333466399215
# Max, Min, DIV : 8.055815764462793e-08, -1.7198553054365712e-07
#
#
# ------------ Time = 8.19999999999987 ---------------
# Number of poisson iterations    : 516
# Final poisson residual : 9.97972299055697e-10
# Max, Min, U   : 2.0, -0.239523430539713
# Max, Min, V   : 0.34642638997649533, -0.5190258614998139
# Max, Min, P   : 1.31301279131145, -0.6858242340379199
# Max, Min, DIV : 8.120665245803238e-08, -1.7189774306411443e-07
#
#
# ------------ Time = 8.299999999999867 ---------------
# Number of poisson iterations    : 502
# Final poisson residual : 9.982518291259857e-10
# Max, Min, U   : 2.0, -0.23954068218958863
# Max, Min, V   : 0.34642716900440346, -0.5190462736947619
# Max, Min, P   : 1.313056596131879, -0.685815594587469
# Max, Min, DIV : 8.20209860585841e-08, -1.717639324340034e-07
#
#
# ------------ Time = 8.399999999999865 ---------------
# Number of poisson iterations    : 488
# Final poisson residual : 9.989785162086537e-10
# Max, Min, U   : 2.0, -0.23955690940330926
# Max, Min, V   : 0.34642790602982976, -0.5190655919353916
# Max, Min, P   : 1.3130980913086951, -0.6858074038221549
# Max, Min, DIV : 8.311778071368181e-08, -1.71564497617252e-07
#
#
# ------------ Time = 8.499999999999863 ---------------
# Number of poisson iterations    : 475
# Final poisson residual : 9.991208365613622e-10
# Max, Min, U   : 2.0, -0.23957217900306924
# Max, Min, V   : 0.34642860338494535, -0.5190838759463445
# Max, Min, P   : 1.3131374022122826, -0.6857996377931026
# Max, Min, DIV : 8.41578373655949e-08, -1.7118130998805547e-07
#
#
# ------------ Time = 8.599999999999861 ---------------
# Number of poisson iterations    : 462
# Final poisson residual : 9.996579728043971e-10
# Max, Min, U   : 2.0, -0.23958655282022537
# Max, Min, V   : 0.34642926323437373, -0.5191011820148154
# Max, Min, P   : 1.3131746404842881, -0.6857922753424477
# Max, Min, DIV : 8.540262302902946e-08, -1.7072832463310011e-07
#
#
# ------------ Time = 8.699999999999859 ---------------
# Number of poisson iterations    : 450
# Final poisson residual : 9.972361418457372e-10
# Max, Min, U   : 2.0, -0.23960008818243547
# Max, Min, V   : 0.34642988764849125, -0.5191175633197758
# Max, Min, P   : 1.3132099162892081, -0.6857852963086909
# Max, Min, DIV : 8.629789521874542e-08, -1.6968761382823994e-07
#
#
# ------------ Time = 8.799999999999857 ---------------
# Number of poisson iterations    : 437
# Final poisson residual : 9.990255407574286e-10
# Max, Min, U   : 2.0, -0.23961283821611318
# Max, Min, V   : 0.3464304785366245, -0.5191330699409622
# Max, Min, P   : 1.313243332192681, -0.6857786786558118
# Max, Min, DIV : 8.782164828691208e-08, -1.691879836914975e-07
#
#
# ------------ Time = 8.899999999999855 ---------------
# Number of poisson iterations    : 425
# Final poisson residual : 9.992527501571553e-10
# Max, Min, U   : 2.0, -0.23962485231372496
# Max, Min, V   : 0.3464310377657701, -0.5191477493263388
# Max, Min, P   : 1.3132749887010269, -0.6857724054391685
# Max, Min, DIV : 8.917466765012705e-08, -1.6836099900070095e-07
#
#
# ------------ Time = 8.999999999999853 ---------------
# Number of poisson iterations    : 414
# Final poisson residual : 9.975620784851395e-10
# Max, Min, U   : 2.0, -0.2396361763368498
# Max, Min, V   : 0.34643156706363654, -0.5191616461965606
# Max, Min, P   : 1.3133049788888638, -0.68576645861353
# Max, Min, DIV : 9.021072944204178e-08, -1.6719520540536131e-07
#
#
# ------------ Time = 9.09999999999985 ---------------
# Number of poisson iterations    : 403
# Final poisson residual : 9.967818699629957e-10
# Max, Min, U   : 2.0, -0.2396468529201462
# Max, Min, V   : 0.3464320680342608, -0.5191748027305365
# Max, Min, P   : 1.313333388898036, -0.6857608203144034
# Max, Min, DIV : 9.135250167435771e-08, -1.6609215364605384e-07
# ------------ Time = 9.199999999999848 ---------------
# Number of poisson iterations    : 391
# Final poisson residual : 9.996538767296538e-10
# Max, Min, U   : 2.0, -0.23965692175456957
# Max, Min, V   : 0.3464325422045425, -0.5191872588023264
# Max, Min, P   : 1.3133602991210707, -0.6857554760987739
# Max, Min, DIV : 9.311812376733286e-08, -1.6533299322489536e-07
#
#
# ------------ Time = 9.299999999999846 ---------------
# Number of poisson iterations    : 381
# Final poisson residual : 9.966449181594954e-10
# Max, Min, U   : 2.0, -0.23966641988279416
# Max, Min, V   : 0.3464329910779808, -0.5191990522316037
# Max, Min, P   : 1.313385794361284, -0.6857504102976899
# Max, Min, DIV : 9.405591361311139e-08, -1.637571375228894e-07
#
#
# ------------ Time = 9.399999999999844 ---------------
# Number of poisson iterations    : 370
# Final poisson residual : 9.969320773057468e-10
# Max, Min, U   : 2.0, -0.23967538173627384
# Max, Min, V   : 0.34643341596737404, -0.5192102184996402
# Max, Min, P   : 1.3134099437408582, -0.6857456082131745
# Max, Min, DIV : 9.549454005330915e-08, -1.6247048536394137e-07
#
#
# ------------ Time = 9.499999999999842 ---------------
# Number of poisson iterations    : 359
# Final poisson residual : 9.99960201748271e-10
# Max, Min, U   : 2.0, -0.23968383951358202
# Max, Min, V   : 0.34643381819268626, -0.5192207913150328
# Max, Min, P   : 1.3134328217516311, -0.6857410556588874
# Max, Min, DIV : 9.719663129903466e-08, -1.6153067487582884e-07
#
#
# ------------ Time = 9.59999999999984 ---------------
# Number of poisson iterations    : 349
# Final poisson residual : 9.991667830391144e-10
# Max, Min, U   : 2.0, -0.23969182328383407
# Max, Min, V   : 0.3464341989976489, -0.5192308025684622
# Max, Min, P   : 1.3134544947348348, -0.6857367413766295
# Max, Min, DIV : 9.836557290920922e-08, -1.6002488407822202e-07
#
#
# ------------ Time = 9.699999999999838 ---------------
# Number of poisson iterations    : 339
# Final poisson residual : 9.995141500973537e-10
# Max, Min, U   : 2.0, -0.23969936110016882
# Max, Min, V   : 0.34643455951047736, -0.5192402822735336
# Max, Min, P   : 1.3134750257142263, -0.6857326515444291
# Max, Min, DIV : 9.96678450881916e-08, -1.5860619408981924e-07
#
#
# ------------ Time = 9.799999999999836 ---------------
# Number of poisson iterations    : 329
# Final poisson residual : 9.995259822695797e-10
# Max, Min, U   : 2.0, -0.23970647922217955
# Max, Min, V   : 0.3464349008228508, -0.519249258877598
# Max, Min, P   : 1.313494473743417, -0.6857287753081197
# Max, Min, DIV : 1.0098652747370096e-07, -1.5702002860266961e-07
#
#
# ------------ Time = 9.899999999999833 ---------------
# Number of poisson iterations    : 320
# Final poisson residual : 9.980685500605318e-10
# Max, Min, U   : 2.0, -0.23971320223223475
# Max, Min, V   : 0.34643522399205806, -0.5192577593158194
# Max, Min, P   : 1.3135128994537633, -0.6857251007920873
# Max, Min, DIV : 1.020816015051551e-07, -1.5533881411559924e-07
#
#
# ------------ Time = 9.999999999999831 ---------------
# Number of poisson iterations    : 311
# Final poisson residual : 9.976899526767745e-10
# Max, Min, U   : 2.0, -0.2397195531044793
# Max, Min, V   : 0.34643552997565996, -0.5192658089876258
# Max, Min, P   : 1.3135303544212813, -0.6857216179945804
# Max, Min, DIV : 1.03294899300721e-07, -1.5375639006789954e-07

# %%
flowx.io.plot_contour(gridc, 'pres')
flowx.io.plot_vector(gridx,gridy,'velc')

# %%
gridx.get_l2_norm('eror')
# Out:
# 0.0
