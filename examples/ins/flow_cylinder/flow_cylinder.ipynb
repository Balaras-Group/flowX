# %%
# Sample API
import flowx
import simulation
flowx.__version__
# Out:
# '0.1.dev'

# %%
# Define grid parameters
D = 1
nx, ny = 100, 50

xmin, xmax = -10*D, 30*D
ymin, ymax = -10*D, 10*D

Re   = 100.0
dt   = .01
tmax = 10.

ibm_x = 0.0
ibm_y = 0.0
ibm_r = 0.5

# Define cell-centered variable names
center_vars = ['pres', 'divv']
face_vars   = ['velc', 'hvar']

# Define boundary conditions for variable pressure and velocity [left, right, bottom, top]
bc_type_pres = {'pres': ['neumann', 'neumann', 'neumann', 'neumann']}
bc_val_pres  = {'pres': [0.0, 0.0, 0.0, 0.0]}

bc_type_u = {'velc': ['dirichlet', 'outflow', 'dirichlet', 'dirichlet']}
bc_val_u  = {'velc': [1.0, 0.0, 0.0, 0.0]}

bc_type_v = {'velc': ['dirichlet', 'neumann', 'dirichlet', 'dirichlet']}
bc_val_v  = {'velc': [0.0, 0.0, 0.0, 0.0]}


# Create the grid and data
gridc = flowx.Grid('cell-centered', center_vars,
                    nx, ny, xmin, xmax, ymin, ymax,
                    user_bc_type=bc_type_pres, user_bc_val=bc_val_pres)

gridx = flowx.Grid('x-face', face_vars,
                    nx, ny, xmin, xmax, ymin, ymax,
                    user_bc_type=bc_type_u, user_bc_val=bc_val_u)

gridy = flowx.Grid('y-face', face_vars,
                    nx, ny, xmin, xmax, ymin, ymax,
                    user_bc_type=bc_type_v, user_bc_val=bc_val_v)

scalars = flowx.Scalars(tmax=10.0, dt=0.01, Re=100.0)

# %%
simulation.set_initial_velocity(gridc, gridx, gridy, 'velc', 'pres')
idxsx, idxnotx = simulation.tag( gridx, D )
idxsy, idxnoty = simulation.tag( gridy, D )
vfracx = simulation.vfrac( gridx, idxsx, D )
vfracy = simulation.vfrac( gridy, idxsy, D )
simulation.apply_ibm( gridx, idxsx, idxnotx, vfracx )
simulation.apply_ibm( gridy, idxsy, idxnoty, vfracy )

# %%
ins_vars = ['velc', 'hvar', 'divv', 'pres']

poisson_options = dict(maxiter = 2000, tol = 1e-9)
poisson_options['lu'], poisson_options['mtx'] = flowx.poisson.build_sparse(gridc, 'pres')

# Compute mass in the domain
Qin = (simulation.get_qin(gridx, 'velc', bc_type_u['velc']) +
       simulation.get_qin(gridy, 'velc', bc_type_v['velc']))

# Update the outflow boundary velocity using a convective equation.
simulation.update_outflow_bc(gridx, 'velc', dt)

# Predictor Step
flowx.ins.advance_euler(gridc, gridx, gridy, scalars, ins_vars, 'predictor')

# ibm
simulation.apply_ibm( gridx, idxsx, idxnotx, vfracx )
simulation.apply_ibm( gridy, idxsy, idxnoty, vfracy )

# Divergence Step
flowx.ins.advance_euler(gridc, gridx, gridy, scalars, ins_vars, 'divergence')

# Compute mass out of the domain
Qout = (simulation.get_qout(gridx, 'velc', bc_type_u['velc']) +
        simulation.get_qout(gridy, 'velc', bc_type_v['velc']))

# Rescale velocity at outflow and update BC for corrector step
simulation.rescale_velocity(gridx, 'velc', bc_type_u['velc'],
                            Qin, Qout) 
simulation.update_outflow_bc(gridx, 'velc', dt, convvel=0.0)

# Solve the pressure Poisson equation 
scalars.stats['ites'], scalars.stats['res'] = flowx.poisson.solve_lu(gridc, 'pres', 'divv', 
                                                                         poisson_options)


# Corrector Step
flowx.ins.advance_euler(gridc, gridx, gridy, scalars, ins_vars, 'corrector')

scalars.advance()

while scalars.variable['time'] <= scalars.variable['tmax']:
    
    # Compute mass in the domain
    Qin = (simulation.get_qin(gridx, 'velc', bc_type_u['velc']) +
           simulation.get_qin(gridy, 'velc', bc_type_v['velc']))
    
    # Update the outflow boundary velocity using a convective equation.
    simulation.update_outflow_bc(gridx, 'velc', dt)
    
    # Predictor Step
    flowx.ins.ab2(gridc, gridx, gridy, scalars, ins_vars, 'predictor')
    
    #ibm
    simulation.apply_ibm( gridx, idxsx, idxnotx, vfracx )
    simulation.apply_ibm( gridy, idxsy, idxnoty, vfracy )

    
    # Divergence Step
    flowx.ins.ab2(gridc, gridx, gridy, scalars, ins_vars, 'divergence')
    
    # Compute mass out of the domain
    Qout = (simulation.get_qout(gridx, 'velc', bc_type_u['velc']) +
            simulation.get_qout(gridy, 'velc', bc_type_v['velc']))
    
    # Rescale velocity at outflow and update BC for corrector step
    simulation.rescale_velocity(gridx, 'velc', bc_type_u['velc'],
                                Qin, Qout) 
    simulation.update_outflow_bc(gridx, 'velc', dt, convvel=0.0)
    
    # Solve the pressure Poisson equation 
    scalars.stats['ites'], scalars.stats['res'] = flowx.poisson.solve_lu(gridc, 'pres', 'divv', 
                                                                             poisson_options)
    
    
    # Corrector Step
    flowx.ins.ab2(gridc, gridx, gridy, scalars, ins_vars, 'corrector')
    
    # Display stats
    if scalars.variable['nstep'] % 10 == 0:
        flowx.io.display_stats(scalars)  
        
    if scalars.variable['nstep'] % 100 == 0:
        flowx.io.plot_contour(gridc, 'pres')
        flowx.io.plot_contour(gridx, 'velc')
        flowx.io.plot_vector(gridx,gridy,'velc')
              
    scalars.advance()
# Out:
# ------------ Time = 0.09999999999999999 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 8.023160292124791e-14
# Max, Min, U   : 1.356722561815368, -1.0
# Max, Min, V   : 0.6351983254070793, -0.6351983254070794
# Max, Min, P   : 0.527140958673596, -0.08835478461279155
# Max, Min, DIV : 5.312082425410619e-16, -5.473865718336191e-16
#
#
# ------------ Time = 0.20000000000000004 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 5.027433071660708e-14
# Max, Min, U   : 1.3574005898572916, -1.0
# Max, Min, V   : 0.675300873964914, -0.6753008739649141
# Max, Min, P   : 0.41736520345220984, -0.2070228002405906
# Max, Min, DIV : 5.525636372072373e-16, -5.522654816098038e-16
#
#
# ------------ Time = 0.3000000000000001 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.7498253377154473e-14
# Max, Min, U   : 1.3513413019655918, -1.0
# Max, Min, V   : 0.7131073054901136, -0.7131073054901136
# Max, Min, P   : 0.3265765800419311, -0.3129259075073102
# Max, Min, DIV : 5.464378949326942e-16, -5.551115123125783e-16
#
#
# ------------ Time = 0.4000000000000002 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.5081053803114358e-14
# Max, Min, U   : 1.338173118534017, -1.0
# Max, Min, V   : 0.7481957344184477, -0.7481957344184476
# Max, Min, P   : 0.17774718325173172, -0.47721012863688295
# Max, Min, DIV : 5.397971566262205e-16, -5.325330020705676e-16
#
#
# ------------ Time = 0.5000000000000002 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.911660772834167e-14
# Max, Min, U   : 1.3179942219235024, -1.0
# Max, Min, V   : 0.7801598531514323, -0.7801598531514322
# Max, Min, P   : 0.3173870595837375, -0.36524520790164555
# Max, Min, DIV : 5.447031714567174e-16, -5.529431079676073e-16
#
#
# ------------ Time = 0.6000000000000003 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 7.9559937199547e-14
# Max, Min, U   : 1.291401952474821, -1.0
# Max, Min, V   : 0.808702395011382, -0.808702395011382
# Max, Min, P   : -0.002796761040871923, -0.7166544262297395
# Max, Min, DIV : 5.408834763810742e-16, -5.538240222327517e-16
#
#
# ------------ Time = 0.7000000000000004 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.1831471882598e-13
# Max, Min, U   : 1.263284854829638, -1.0
# Max, Min, V   : 0.8336544034076072, -0.8336544034076072
# Max, Min, P   : -0.13680934534781788, -0.8791925786155235
# Max, Min, DIV : 5.421010862427522e-16, -5.663872149064275e-16
#
#
# ------------ Time = 0.8000000000000005 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.1022626989799094e-13
# Max, Min, U   : 1.27231500639061, -1.0
# Max, Min, V   : 0.8549812796825433, -0.8549812796825433
# Max, Min, P   : -0.08555693471093496, -0.8530396910209371
# Max, Min, DIV : 5.676306592729968e-16, -5.59990422088763e-16
#
#
# ------------ Time = 0.9000000000000006 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.1454078755601414e-13
# Max, Min, U   : 1.2784624262800304, -1.0
# Max, Min, V   : 0.8727752400210924, -0.8727752400210925
# Max, Min, P   : -0.4786683298925275, -1.2672642586583815
# Max, Min, DIV : 5.587537539857718e-16, -5.667666856667974e-16
#
#
# ------------ Time = 1.0000000000000007 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.0282085618315074e-13
# Max, Min, U   : 1.2814367372201922, -1.0
# Max, Min, V   : 0.8872363135255225, -0.8872363135255226
# Max, Min, P   : -0.3885111465612866, -1.1939240283061745
# Max, Min, DIV : 5.968024739764349e-16, -5.598413442900463e-16
# ------------ Time = 1.1000000000000008 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.304420549533452e-13
# Max, Min, U   : 1.281245380643722, -1.0
# Max, Min, V   : 0.8986456931197525, -0.8986456931197527
# Max, Min, P   : -0.12531037941617362, -0.9432173034674901
# Max, Min, DIV : 5.659535340374333e-16, -5.55653613398821e-16
#
#
# ------------ Time = 1.2000000000000008 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.4291696847644478e-13
# Max, Min, U   : 1.2781725584555554, -1.0
# Max, Min, V   : 0.9073359271468756, -0.9073359271468759
# Max, Min, P   : -0.1705825361648461, -0.996899784289562
# Max, Min, DIV : 5.602072625232601e-16, -5.487418245492259e-16
#
#
# ------------ Time = 1.300000000000001 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.1103389715664939e-13
# Max, Min, U   : 1.2727334709647402, -1.0
# Max, Min, V   : 0.913662182714586, -0.9136621827145862
# Max, Min, P   : -0.03823181436787516, -0.8693253768252948
# Max, Min, DIV : 5.637851296924623e-16, -5.711712569925198e-16
#
#
# ------------ Time = 1.400000000000001 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.5694115993254195e-13
# Max, Min, U   : 1.27246641427584, -1.0
# Max, Min, V   : 0.9179778505623748, -0.9179778505623749
# Max, Min, P   : -0.21302370153314637, -1.0458436609861188
# Max, Min, DIV : 5.551115123125783e-16, -5.784218590210166e-16
#
#
# ------------ Time = 1.500000000000001 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.7508037571157822e-13
# Max, Min, U   : 1.2773395326053218, -1.0
# Max, Min, V   : 0.9206164089194409, -0.9206164089194409
# Max, Min, P   : -0.26753789298420294, -1.0996736423658826
# Max, Min, DIV : 5.963111948670274e-16, -5.668208957754217e-16
#
#
# ------------ Time = 1.6000000000000012 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.1149089733145926e-13
# Max, Min, U   : 1.2788762102730706, -1.0
# Max, Min, V   : 0.9218800528006801, -0.9218800528006802
# Max, Min, P   : -0.4176530834460819, -1.2473205804937069
# Max, Min, DIV : 8.881784197001252e-16, -5.848186518386811e-16
#
#
# ------------ Time = 1.7000000000000013 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.244728967519176e-13
# Max, Min, U   : 1.2772723831051598, -1.0
# Max, Min, V   : 0.9220344151257177, -0.9220344151257177
# Max, Min, P   : -0.4793415881316737, -1.305322309793433
# Max, Min, DIV : 5.807427292964934e-16, -6.006480035569695e-16
#
#
# ------------ Time = 1.8000000000000014 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.2714845900126205e-13
# Max, Min, U   : 1.2763915909511927, -1.0
# Max, Min, V   : 0.9213079510494843, -0.9213079510494844
# Max, Min, P   : -0.49619837980855863, -1.3177518437107765
# Max, Min, DIV : 5.846560215128083e-16, -6.217010074609751e-16
#
#
# ------------ Time = 1.9000000000000015 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.004197037230043e-13
# Max, Min, U   : 1.276352226433979, -1.0
# Max, Min, V   : 0.9198942930545891, -0.9198942930545891
# Max, Min, P   : -0.3707607755213321, -1.1875295211813306
# Max, Min, DIV : 5.603156827405087e-16, -5.867431106948429e-16
#
#
# ------------ Time = 2.0000000000000013 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.2315256187736083e-13
# Max, Min, U   : 1.2740825237922582, -1.0
# Max, Min, V   : 0.9179560496682088, -0.9179560496682083
# Max, Min, P   : -0.4847270510720892, -1.2966469028970464
# Max, Min, DIV : 6.030874584450618e-16, -5.681219383824043e-16
# ------------ Time = 2.099999999999999 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.2942861801397124e-13
# Max, Min, U   : 1.269860330429671, -1.0
# Max, Min, V   : 0.9156289594365472, -0.9156289594365467
# Max, Min, P   : -0.506111433285232, -1.3133330799847007
# Max, Min, DIV : 5.551115123125783e-16, -5.941427905220564e-16
#
#
# ------------ Time = 2.199999999999997 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.6102076658594907e-13
# Max, Min, U   : 1.2640925263388207, -1.0
# Max, Min, V   : 0.9130258321535825, -0.9130258321535822
# Max, Min, P   : -0.2357818701057417, -1.0386042952278518
# Max, Min, DIV : 5.555858507630407e-16, -5.464378949326942e-16
#
#
# ------------ Time = 2.299999999999995 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.8392435301489587e-13
# Max, Min, U   : 1.2572735488563165, -1.0
# Max, Min, V   : 0.9102401434559146, -0.9102401434559144
# Max, Min, P   : -0.3282528849918286, -1.1270661333725918
# Max, Min, DIV : 5.712390196283001e-16, -5.702903427273753e-16
#
#
# ------------ Time = 2.399999999999993 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.9627459642853205e-13
# Max, Min, U   : 1.2499411896569903, -1.0
# Max, Min, V   : 0.9073493958993346, -0.9073493958993343
# Max, Min, P   : -0.3587152698875348, -1.1539495976751506
# Max, Min, DIV : 5.595567412197688e-16, -5.854691731421724e-16
#
#
# ------------ Time = 2.4999999999999907 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.0282861574416239e-13
# Max, Min, U   : 1.2440853072521547, -1.0
# Max, Min, V   : 0.9044184003852925, -0.9044184003852924
# Max, Min, P   : -0.017537118736993814, -0.8096170696511501
# Max, Min, DIV : 8.881784197001252e-16, -5.610068616254682e-16
#
#
# ------------ Time = 2.5999999999999885 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.4284928766241902e-13
# Max, Min, U   : 1.239885155016242, -1.0
# Max, Min, V   : 0.9015025163294123, -0.901502516329412
# Max, Min, P   : -0.1834669479615015, -0.9727711805685954
# Max, Min, DIV : 5.488773498207866e-16, -5.713745448998608e-16
#
#
# ------------ Time = 2.6999999999999864 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.2523649541041266e-13
# Max, Min, U   : 1.2429036120818682, -1.0
# Max, Min, V   : 0.8986507064285764, -0.8986507064285761
# Max, Min, P   : -0.10206880974312253, -0.8888984101929089
# Max, Min, DIV : 5.507747036226363e-16, -5.616167253474913e-16
#
#
# ------------ Time = 2.7999999999999843 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.9255257939132541e-13
# Max, Min, U   : 1.245018905497163, -1.0
# Max, Min, V   : 0.8959081060098545, -0.895908106009854
# Max, Min, P   : -0.35160738199819963, -1.1361661261752358
# Max, Min, DIV : 5.724587470723463e-16, -5.793976409762536e-16
#
#
# ------------ Time = 2.899999999999982 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.144047227820974e-13
# Max, Min, U   : 1.245949379762139, -1.0
# Max, Min, V   : 0.8933177474945048, -0.8933177474945044
# Max, Min, P   : -0.4361154351571068, -1.21850474174867
# Max, Min, DIV : 5.540273101400928e-16, -5.76524505219167e-16
#
#
# ------------ Time = 2.99999999999998 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.1900558409256419e-13
# Max, Min, U   : 1.2455443486487023, -1.0
# Max, Min, V   : 0.8909211467795121, -0.8909211467795117
# Max, Min, P   : -0.43699219313444526, -1.217221582711513
# Max, Min, DIV : 5.499073418846478e-16, -5.778797579347739e-16
# ------------ Time = 3.099999999999978 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.051968489384888e-13
# Max, Min, U   : 1.2437909394832207, -1.0
# Max, Min, V   : 0.888757636053813, -0.8887576360538127
# Max, Min, P   : -0.4051918088427221, -1.1832031567128674
# Max, Min, DIV : 5.629177679544739e-16, -5.654114329511906e-16
#
#
# ------------ Time = 3.1999999999999758 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.7125449438338932e-13
# Max, Min, U   : 1.2408084705823421, -1.0
# Max, Min, V   : 0.8868625674896197, -0.8868625674896193
# Max, Min, P   : -0.2772304437748908, -1.0529319138800195
# Max, Min, DIV : 5.946848916082992e-16, -5.449200118912145e-16
#
#
# ------------ Time = 3.2999999999999736 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.1555586289349384e-13
# Max, Min, U   : 1.2368316829192945, -1.0
# Max, Min, V   : 0.8852647470481214, -0.8852647470481211
# Max, Min, P   : -0.46007842861310005, -1.2333823366958874
# Max, Min, DIV : 5.551115123125783e-16, -5.881796785733862e-16
#
#
# ------------ Time = 3.3999999999999715 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.0861913206919722e-13
# Max, Min, U   : 1.2321849061473036, -1.0
# Max, Min, V   : 0.8839836224186888, -0.8839836224186889
# Max, Min, P   : -0.40939382860320195, -1.1802521924155092
# Max, Min, DIV : 5.778797579347739e-16, -5.870954764009007e-16
#
#
# ------------ Time = 3.4999999999999694 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.3499401968867717e-13
# Max, Min, U   : 1.2325269213082497, -1.0
# Max, Min, V   : 0.8830268002595076, -0.8830268002595076
# Max, Min, P   : -0.53644337129572, -1.3048756352804842
# Max, Min, DIV : 5.789639601072594e-16, -8.881784197001252e-16
#
#
# ------------ Time = 3.5999999999999672 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.965925353756304e-13
# Max, Min, U   : 1.2366579411873033, -1.0
# Max, Min, V   : 0.8823883949977168, -0.8823883949977168
# Max, Min, P   : -0.7880974209232419, -1.554206565548727
# Max, Min, DIV : 6.071532165918825e-16, -6.158268339717665e-16
#
#
# ------------ Time = 3.699999999999965 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.556144190207369e-13
# Max, Min, U   : 1.2405742900119332, -1.0
# Max, Min, V   : 0.88204853861214, -0.88204853861214
# Max, Min, P   : -0.6215245793515626, -1.3855001015346398
# Max, Min, DIV : 6.179952383167375e-16, -5.702903427273753e-16
#
#
# ------------ Time = 3.799999999999963 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.685369550285826e-13
# Max, Min, U   : 1.2439653766352907, -1.0
# Max, Min, V   : 0.8819741572975404, -0.8819741572975401
# Max, Min, P   : -0.2634408553498854, -1.0255494114504458
# Max, Min, DIV : 5.561957144850638e-16, -5.606680484465665e-16
#
#
# ------------ Time = 3.899999999999961 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.129197939503823e-13
# Max, Min, U   : 1.2465834656306902, -1.0
# Max, Min, V   : 0.8821209042548983, -0.8821209042548982
# Max, Min, P   : -0.06695979239518303, -0.8275261544015879
# Max, Min, DIV : 5.709408640308666e-16, -5.401495223322783e-16
#
#
# ------------ Time = 3.9999999999999587 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.573623137720874e-14
# Max, Min, U   : 1.2482583944324253, -1.0
# Max, Min, V   : 0.882435976034114, -0.8824359760341138
# Max, Min, P   : 0.33998978769391125, -0.41939228568180326
# Max, Min, DIV : 5.480641981914225e-16, -5.551115123125783e-16
# ------------ Time = 4.099999999999957 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 5.3366144774667055e-14
# Max, Min, U   : 1.2489048908242733, -1.0
# Max, Min, V   : 0.8828614585286505, -0.8828614585286505
# Max, Min, P   : 0.16474196870208543, -0.5938199211824201
# Max, Min, DIV : 5.442694905877232e-16, -5.529431079676073e-16
#
#
# ------------ Time = 4.199999999999955 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.4510484728032666e-13
# Max, Min, U   : 1.248522501180635, -1.0
# Max, Min, V   : 0.8833378475360933, -0.8833378475360936
# Max, Min, P   : -0.1968342649056987, -0.9549208699456663
# Max, Min, DIV : 5.464378949326942e-16, -5.7462715141731735e-16
#
#
# ------------ Time = 4.299999999999953 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.0796808087012205e-13
# Max, Min, U   : 1.2471888621470324, -1.0
# Max, Min, V   : 0.8838074466599962, -0.8838074466599964
# Max, Min, P   : -0.39842995992214497, -1.1563455860280467
# Max, Min, DIV : 5.681219383824043e-16, -6.002753090601776e-16
#
#
# ------------ Time = 4.399999999999951 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.5413387836808032e-13
# Max, Min, U   : 1.2450475871090592, -1.0
# Max, Min, V   : 0.8842174311528431, -0.8842174311528435
# Max, Min, P   : -0.2266372033576912, -0.9846295479366354
# Max, Min, DIV : 5.442694905877232e-16, -5.681219383824043e-16
#
#
# ------------ Time = 4.4999999999999485 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.7064704056908786e-14
# Max, Min, U   : 1.242292344823103, -1.0
# Max, Min, V   : 0.8845224504178065, -0.884522450417807
# Max, Min, P   : 0.40020035713747565, -0.35804949126832725
# Max, Min, DIV : 5.399326818977812e-16, -5.377642775528102e-16
#
#
# ------------ Time = 4.599999999999946 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 5.860120976773308e-14
# Max, Min, U   : 1.2391487845809688, -1.0
# Max, Min, V   : 0.8846867041489193, -0.88468670414892
# Max, Min, P   : 0.5815016337662551, -0.17711464748448302
# Max, Min, DIV : 5.412337245047638e-16, -5.549488819867054e-16
#
#
# ------------ Time = 4.699999999999944 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.7888755738291394e-14
# Max, Min, U   : 1.2358558553756551, -1.0
# Max, Min, V   : 0.8846854600043235, -0.8846854600043242
# Max, Min, P   : 0.4066506720017457, -0.35236884523353934
# Max, Min, DIV : 5.536478393797228e-16, -5.457467160477347e-16
#
#
# ------------ Time = 4.799999999999942 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.2540986104887493e-13
# Max, Min, U   : 1.233160098307375, -1.0
# Max, Min, V   : 0.884505988198089, -0.8845059881980899
# Max, Min, P   : -0.11787338779874827, -0.8772645056932161
# Max, Min, DIV : 5.551115123125783e-16, -5.724587470723463e-16
#
#
# ------------ Time = 4.89999999999994 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 9.351094755936319e-14
# Max, Min, U   : 1.2353983646111255, -1.0
# Max, Min, V   : 0.8841478819708481, -0.8841478819708491
# Max, Min, P   : 0.015055515645245628, -0.7446141897452726
# Max, Min, DIV : 5.507747036226363e-16, -5.464921050413185e-16
#
#
# ------------ Time = 4.999999999999938 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.0376271203841681e-13
# Max, Min, U   : 1.2365889673385997, -1.0
# Max, Min, V   : 0.883622727034853, -0.8836227270348539
# Max, Min, P   : -0.030485034604905387, -0.7902889454102138
# Max, Min, DIV : 5.614812000759306e-16, -5.702903427273753e-16
# ------------ Time = 5.099999999999936 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 8.961811324570215e-14
# Max, Min, U   : 1.2366340215793994, -1.0
# Max, Min, V   : 0.8829530909374068, -0.8829530909374077
# Max, Min, P   : 0.03273850819973962, -0.7270164622331096
# Max, Min, DIV : 5.593127957309596e-16, -8.881784197001252e-16
#
#
# ------------ Time = 5.199999999999934 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.150223370261426e-13
# Max, Min, U   : 1.235535216254009, -1.0
# Max, Min, V   : 0.8821708331857432, -0.8821708331857441
# Max, Min, P   : -0.07497068242272517, -0.834469583897522
# Max, Min, DIV : 5.377642775528102e-16, -5.627009275199768e-16
#
#
# ------------ Time = 5.299999999999931 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.549043388780984e-13
# Max, Min, U   : 1.23338992903202, -1.0
# Max, Min, V   : 0.881314790055009, -0.8813147900550099
# Max, Min, P   : -0.22711998848571124, -0.9861480391649482
# Max, Min, DIV : 5.38306378639053e-16, -5.724587470723463e-16
#
#
# ------------ Time = 5.399999999999929 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 9.892506074511707e-14
# Max, Min, U   : 1.2303795013257885, -1.0
# Max, Min, V   : 0.8804279573268311, -0.8804279573268319
# Max, Min, P   : -0.010638952527308121, -0.7689906780273829
# Max, Min, DIV : 5.561957144850638e-16, -5.627009275199768e-16
#
#
# ------------ Time = 5.499999999999927 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 6.940522447913678e-14
# Max, Min, U   : 1.226751170413543, -1.0
# Max, Min, V   : 0.8795543659895289, -0.8795543659895299
# Max, Min, P   : 0.0997421278304464, -0.6577534926162046
# Max, Min, DIV : 5.572799166575493e-16, -5.468715758016884e-16
#
#
# ------------ Time = 5.599999999999925 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 5.579270037040176e-14
# Max, Min, U   : 1.226552702384001, -1.0
# Max, Min, V   : 0.8787359029193595, -0.8787359029193603
# Max, Min, P   : 0.15229003799859528, -0.6042098142830177
# Max, Min, DIV : 5.464378949326942e-16, -5.551115123125783e-16
#
#
# ------------ Time = 5.699999999999923 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 7.595297216821741e-14
# Max, Min, U   : 1.2283139702957246, -1.0
# Max, Min, V   : 0.8780093549509023, -0.8780093549509032
# Max, Min, P   : 0.08055099463927318, -0.6748646075503102
# Max, Min, DIV : 5.377642775528102e-16, -5.696127163695719e-16
#
#
# ------------ Time = 5.799999999999921 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.017643359628096e-13
# Max, Min, U   : 1.2302646169596987, -1.0
# Max, Min, V   : 0.8774039411157629, -0.8774039411157634
# Max, Min, P   : -0.0207626365965391, -0.7750632292203882
# Max, Min, DIV : 8.881784197001252e-16, -5.563312397566245e-16
#
#
# ------------ Time = 5.899999999999919 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.4338877382900488e-13
# Max, Min, U   : 1.232236685785674, -1.0
# Max, Min, V   : 0.8769395443213249, -0.8769395443213253
# Max, Min, P   : -0.19898383356669452, -0.9521976804008876
# Max, Min, DIV : 5.724587470723463e-16, -5.675798372961616e-16
#
#
# ------------ Time = 5.9999999999999165 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.381292910551441e-13
# Max, Min, U   : 1.234072076650645, -1.0
# Max, Min, V   : 0.8766257701867497, -0.87662577018675
# Max, Min, P   : -0.16929628228681617, -0.921506616045772
# Max, Min, DIV : 5.637851296924623e-16, -8.881784197001252e-16
# ------------ Time = 6.099999999999914 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.9546640902584784e-13
# Max, Min, U   : 1.2356342634274515, -1.0
# Max, Min, V   : 0.8764618636790533, -0.8764618636790537
# Max, Min, P   : -0.37431410317895947, -1.125650251417604
# Max, Min, DIV : 5.477931476483011e-16, -5.724587470723463e-16
#
#
# ------------ Time = 6.199999999999912 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.462543597441166e-13
# Max, Min, U   : 1.2368174388297664, -1.0
# Max, Min, V   : 0.8764374218617983, -0.8764374218617984
# Max, Min, P   : -0.21216406732383022, -0.9627888692478124
# Max, Min, DIV : 5.603156827405087e-16, -5.862823247715365e-16
#
#
# ------------ Time = 6.29999999999991 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.7563572632506827e-13
# Max, Min, U   : 1.2375524364579604, -1.0
# Max, Min, V   : 0.8765337684548398, -0.8765337684548398
# Max, Min, P   : -0.28921873238246437, -1.0393137532555203
# Max, Min, DIV : 5.898059818321144e-16, -5.583641188300348e-16
#
#
# ------------ Time = 6.399999999999908 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.6266365358097208e-13
# Max, Min, U   : 1.2378091659064623, -1.0
# Max, Min, V   : 0.8767258113370616, -0.8767258113370615
# Max, Min, P   : -0.2583293949822597, -1.0080795993152452
# Max, Min, DIV : 5.681219383824043e-16, -5.551115123125783e-16
#
#
# ------------ Time = 6.499999999999906 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.9943029506197255e-13
# Max, Min, U   : 1.2375956803766868, -1.0
# Max, Min, V   : 0.8769841884980839, -0.8769841884980836
# Max, Min, P   : -0.3978829466502647, -1.1474623970349485
# Max, Min, DIV : 5.724587470723463e-16, -6.591949208711867e-16
#
#
# ------------ Time = 6.599999999999904 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.1393641772880037e-13
# Max, Min, U   : 1.2369543182683038, -1.0
# Max, Min, V   : 0.8772775162303235, -0.877277516230323
# Max, Min, P   : -0.4511252249739733, -1.2006850740150312
# Max, Min, DIV : 5.681219383824043e-16, -5.637851296924623e-16
#
#
# ------------ Time = 6.699999999999902 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.359053882475704e-13
# Max, Min, U   : 1.235955581122324, -1.0
# Max, Min, V   : 0.8775745773923662, -0.8775745773923657
# Max, Min, P   : -0.15371765415941327, -0.9033772706315759
# Max, Min, DIV : 5.572799166575493e-16, -5.681219383824043e-16
#
#
# ------------ Time = 6.7999999999998995 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.954906146631259e-13
# Max, Min, U   : 1.234690516002681, -1.0
# Max, Min, V   : 0.8778463189313762, -0.8778463189313755
# Max, Min, P   : -0.36519430462487845, -1.1150359115594282
# Max, Min, DIV : 6.028164079019405e-16, -8.881784197001252e-16
#
#
# ------------ Time = 6.899999999999897 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.7273366129839158e-13
# Max, Min, U   : 1.2332623709450108, -1.0
# Max, Min, V   : 0.878067559841562, -0.8780675598415617
# Max, Min, P   : -0.28203222092861935, -1.0320990027221923
# Max, Min, DIV : 5.906191334614785e-16, -5.593805583667399e-16
#
#
# ------------ Time = 6.999999999999895 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.7794494687119825e-13
# Max, Min, U   : 1.2317782145237386, -1.0
# Max, Min, V   : 0.878218339352369, -0.8782183393523688
# Max, Min, P   : -0.3015324002011267, -1.0518297131877408
# Max, Min, DIV : 5.507747036226363e-16, -5.811323644522304e-16
# ------------ Time = 7.099999999999893 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.0988649101393957e-13
# Max, Min, U   : 1.2303410892442506, -1.0
# Max, Min, V   : 0.8782848590575778, -0.8782848590575778
# Max, Min, P   : -0.4403475712732818, -1.1908466919484457
# Max, Min, DIV : 5.854691731421724e-16, -5.66089059308994e-16
#
#
# ------------ Time = 7.199999999999891 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.860305891362058e-13
# Max, Min, U   : 1.2298236918443803, -1.0
# Max, Min, V   : 0.8782599926977538, -0.878259992697754
# Max, Min, P   : -0.7650593263812497, -1.5157030893750685
# Max, Min, DIV : 6.342582709040201e-16, -6.028164079019405e-16
#
#
# ------------ Time = 7.299999999999889 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 3.575740926180335e-13
# Max, Min, U   : 1.230100694301253, -1.0
# Max, Min, V   : 0.8781433554460678, -0.8781433554460678
# Max, Min, P   : -0.9734495677418894, -1.724159256173601
# Max, Min, DIV : 5.637851296924623e-16, -6.394082312233262e-16
#
#
# ------------ Time = 7.399999999999887 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 3.807569485542803e-13
# Max, Min, U   : 1.2295410651014238, -1.0
# Max, Min, V   : 0.8779409431982159, -0.877940943198216
# Max, Min, P   : -1.0404530811397774, -1.7911359982629562
# Max, Min, DIV : 5.95443833129039e-16, -5.993469609499869e-16
#
#
# ------------ Time = 7.4999999999998845 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 3.8956053747741724e-13
# Max, Min, U   : 1.228211770112111, -1.0
# Max, Min, V   : 0.8776643732828291, -0.8776643732828292
# Max, Min, P   : -1.0909610643020091, -1.8415182994762809
# Max, Min, DIV : 5.984795992119984e-16, -6.131163285405528e-16
#
#
# ------------ Time = 7.599999999999882 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 3.7365552168138716e-13
# Max, Min, U   : 1.2264342060467344, -1.0
# Max, Min, V   : 0.8773297815109845, -0.8773297815109846
# Max, Min, P   : -0.9972364441163925, -1.7475704183936784
# Max, Min, DIV : 6.028164079019405e-16, -6.231994087446679e-16
#
#
# ------------ Time = 7.69999999999988 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.930409749202027e-13
# Max, Min, U   : 1.2265284786823214, -1.0
# Max, Min, V   : 0.8769564550232702, -0.8769564550232706
# Max, Min, P   : -0.7937476028678939, -1.5437690248655282
# Max, Min, DIV : 6.418476861114186e-16, -6.288372600415926e-16
#
#
# ------------ Time = 7.799999999999878 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.804087442470872e-13
# Max, Min, U   : 1.2268831828855764, -1.0
# Max, Min, V   : 0.8765653026860247, -0.876565302686025
# Max, Min, P   : -0.7362992986866332, -1.485933182197518
# Max, Min, DIV : 6.223320470066795e-16, -6.03900610074426e-16
#
#
# ------------ Time = 7.899999999999876 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 3.0226266188829276e-13
# Max, Min, U   : 1.2274467437610672, -1.0
# Max, Min, V   : 0.876177280587419, -0.8761772805874193
# Max, Min, P   : -0.8356270252325227, -1.5848174332744869
# Max, Min, DIV : 5.823520918962766e-16, -6.185373394029803e-16
#
#
# ------------ Time = 7.999999999999874 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.4038387126300413e-13
# Max, Min, U   : 1.2281559665315591, -1.0
# Max, Min, V   : 0.8758118955061128, -0.875811895506113
# Max, Min, P   : -0.5827838237030706, -1.3314970342540935
# Max, Min, DIV : 5.767955557622884e-16, -5.811323644522304e-16
# ------------ Time = 8.099999999999872 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.2620142106402304e-13
# Max, Min, U   : 1.2289415803609194, -1.0
# Max, Min, V   : 0.8754859016397035, -0.8754859016397037
# Max, Min, P   : -0.5373529693030369, -1.2855788285938012
# Max, Min, DIV : 5.963111948670274e-16, -5.908901840045999e-16
#
#
# ------------ Time = 8.19999999999987 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.1246321755282855e-13
# Max, Min, U   : 1.2297339386868835, -1.0
# Max, Min, V   : 0.8752122853967653, -0.8752122853967658
# Max, Min, P   : -0.45191053732987635, -1.1996618887036785
# Max, Min, DIV : 8.881784197001252e-16, -5.551115123125783e-16
#
#
# ------------ Time = 8.299999999999867 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.373666126205061e-13
# Max, Min, U   : 1.230468382787284, -1.0
# Max, Min, V   : 0.8749996022860126, -0.874999602286013
# Max, Min, P   : -0.5651250842482602, -1.3124353286725423
# Max, Min, DIV : 5.824198545320569e-16, -6.091183330295125e-16
#
#
# ------------ Time = 8.399999999999865 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.770567359643632e-13
# Max, Min, U   : 1.2310898182150052, -1.0
# Max, Min, V   : 0.8748516934755048, -0.8748516934755053
# Max, Min, P   : -0.696341740433123, -1.443260776166322
# Max, Min, DIV : 6.002143226879753e-16, -6.797947621484113e-16
#
#
# ------------ Time = 8.499999999999863 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.3984023186618675e-13
# Max, Min, U   : 1.2315561511637085, -1.0
# Max, Min, V   : 0.87476777287173, -0.8747677728717305
# Max, Min, P   : -0.5771268450510942, -1.3237158147809773
# Max, Min, DIV : 5.990217002982412e-16, -6.028164079019405e-16
#
#
# ------------ Time = 8.599999999999861 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.1458710875833367e-13
# Max, Min, U   : 1.231840369206723, -1.0
# Max, Min, V   : 0.8747428435633698, -0.8747428435633702
# Max, Min, P   : -0.46258599100969977, -1.2089113990219085
# Max, Min, DIV : 5.737597896793289e-16, -5.616167253474913e-16
#
#
# ------------ Time = 8.699999999999859 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.8904720711935472e-13
# Max, Min, U   : 1.2319312059220038, -1.0
# Max, Min, V   : 0.8747683787233723, -0.8747683787233727
# Max, Min, P   : -0.3515791935237925, -1.0977070151022665
# Max, Min, DIV : 5.702903427273753e-16, -5.854691731421724e-16
#
#
# ------------ Time = 8.799999999999857 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.0821465420806903e-13
# Max, Min, U   : 1.2318324771932208, -1.0
# Max, Min, V   : 0.8748331881853691, -0.8748331881853695
# Max, Min, P   : -0.4263175940641096, -1.172307971733038
# Max, Min, DIV : 5.78096598369271e-16, -5.637851296924623e-16
#
#
# ------------ Time = 8.899999999999855 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 3.02279309010074e-13
# Max, Min, U   : 1.231561297395344, -1.0
# Max, Min, V   : 0.8749243876885545, -0.8749243876885548
# Max, Min, P   : -0.8018391970491091, -1.5477422091251074
# Max, Min, DIV : 5.898059818321144e-16, -5.898059818321144e-16
#
#
# ------------ Time = 8.999999999999853 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 3.7299910110266984e-13
# Max, Min, U   : 1.231145462771377, -1.0
# Max, Min, V   : 0.8750283916368952, -0.8750283916368955
# Max, Min, P   : -1.0011500197881849, -1.7470028379592117
# Max, Min, DIV : 5.692061405548898e-16, -5.984795992119984e-16
# ------------ Time = 9.09999999999985 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 4.311128575027937e-13
# Max, Min, U   : 1.2306203230032835, -1.0
# Max, Min, V   : 0.8751318598381927, -0.8751318598381932
# Max, Min, P   : -1.278782781832178, -2.0246083382934024
# Max, Min, DIV : 5.767955557622884e-16, -6.7559347873002995e-16
#
#
# ------------ Time = 9.199999999999848 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 4.990853410105619e-13
# Max, Min, U   : 1.2300254548272767, -1.0
# Max, Min, V   : 0.8752225416521449, -0.8752225416521452
# Max, Min, P   : -1.5831110999677003, -2.3289181955165814
# Max, Min, DIV : 6.908536243077634e-16, -7.335982949580044e-16
#
#
# ------------ Time = 9.299999999999846 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 4.671403570450146e-13
# Max, Min, U   : 1.2294014140843015, -1.0
# Max, Min, V   : 0.875289975192332, -0.8752899751923324
# Max, Min, P   : -1.4314478584674768, -2.177232490122099
# Max, Min, DIV : 7.199102425303749e-16, -6.591949208711867e-16
#
#
# ------------ Time = 9.399999999999844 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 4.500247650891589e-13
# Max, Min, U   : 1.2287867878388505, -1.0
# Max, Min, V   : 0.875326013191586, -0.8753260131915863
# Max, Min, P   : -1.3331309324302523, -2.0788785211285274
# Max, Min, DIV : 6.704706234650359e-16, -6.940655732437517e-16
#
#
# ------------ Time = 9.499999999999842 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 4.2020365592974656e-13
# Max, Min, U   : 1.2282157082563627, -1.0
# Max, Min, V   : 0.8753251600115619, -0.8753251600115624
# Max, Min, P   : -1.2407432843679602, -1.9864314456740273
# Max, Min, DIV : 6.071532165918825e-16, -6.2341624917916505e-16
#
#
# ------------ Time = 9.59999999999984 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 3.981370845407656e-13
# Max, Min, U   : 1.2277159336152181, -1.0
# Max, Min, V   : 0.8752847157967545, -0.8752847157967549
# Max, Min, P   : -1.137925216311191, -1.8835267332179608
# Max, Min, DIV : 6.036837696399289e-16, -6.429318882839041e-16
#
#
# ------------ Time = 9.699999999999838 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 3.3533635959353e-13
# Max, Min, U   : 1.2273075536095124, -1.0
# Max, Min, V   : 0.8752047340732441, -0.8752047340732446
# Max, Min, P   : -0.9144263803251929, -1.659912091891484
# Max, Min, DIV : 6.049848122469115e-16, -5.863365348801608e-16
#
#
# ------------ Time = 9.799999999999836 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.989969710199808e-13
# Max, Min, U   : 1.2270023363979978, -1.0
# Max, Min, V   : 0.8750878084419196, -0.8750878084419202
# Max, Min, P   : -0.8158556202705086, -1.5611970137590645
# Max, Min, DIV : 5.898059818321144e-16, -5.952269926945419e-16
#
#
# ------------ Time = 9.899999999999833 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 2.4252447099856005e-13
# Max, Min, U   : 1.2268037013971165, -1.0
# Max, Min, V   : 0.8749387125656742, -0.8749387125656749
# Max, Min, P   : -0.5830478158980077, -1.3282191851612926
# Max, Min, DIV : 5.724587470723463e-16, -6.006480035569695e-16
#
#
# ------------ Time = 9.999999999999831 ---------------
# Number of poisson iterations    : None
# Final poisson residual : 1.9976811356398465e-13
# Max, Min, U   : 1.2267072714746428, -1.0
# Max, Min, V   : 0.8747639252521694, -0.87476392525217
# Max, Min, P   : -0.39568736459048676, -1.1406674606194203
# Max, Min, DIV : 5.843849709696869e-16, -5.681219383824043e-16

# %%
flowx.io.plot_contour(gridc, 'pres')
flowx.io.plot_contour(gridx, 'velc')
flowx.io.plot_vector(gridx, gridy,'velc')
