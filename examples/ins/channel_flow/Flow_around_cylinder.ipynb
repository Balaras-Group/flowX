# %%
# Sample API
import flowx
import simulation
import ibody
flowx.__version__
# Out:
# '0.1.dev'

# %%
# Define grid parameters
nx, ny = 100, 50
xmin, xmax = -3.0, 7.0
ymin, ymax = -2.5, 2.5

Re   = 100.0
dt   = 1e-1
tmax = 10.

ibm_x = 0.0
ibm_y = 0.0
ibm_r = 0.5
Nc    = 50

# Define cell-centered variable names
center_vars = ['pres', 'divv']
face_vars   = ['velc', 'hvar']

# Define boundary conditions for variable pressure and velocity [left, right, bottom, top]
bc_type_pres = {'pres': ['neumann', 'neumann', 'neumann', 'neumann']}
bc_val_pres  = {'pres': [0.0, 0.0, 0.0, 0.0]}

bc_type_u = {'velc': ['dirichlet', 'outflow', 'dirichlet', 'dirichlet']}
bc_val_u  = {'velc': [1.0, 0.0, 0.0, 0.0]}

bc_type_v = {'velc': ['dirichlet', 'neumann', 'dirichlet', 'dirichlet']}
bc_val_v  = {'velc': [0.0, 0.0, 0.0, 0.0]}


# Create the grid and data
gridc = flowx.Grid('cell-centered', center_vars,
                    nx, ny, xmin, xmax, ymin, ymax,
                    user_bc_type=bc_type_pres, user_bc_val=bc_val_pres)

gridx = flowx.Grid('x-face', face_vars,
                    nx, ny, xmin, xmax, ymin, ymax,
                    user_bc_type=bc_type_u, user_bc_val=bc_val_u)

gridy = flowx.Grid('y-face', face_vars,
                    nx, ny, xmin, xmax, ymin, ymax,
                    user_bc_type=bc_type_v, user_bc_val=bc_val_v)

scalars = flowx.Scalars(tmax=10.0, dt=0.01, Re=100.0)

xib, yib = ibody.ib(ibm_x, ibm_y, ibm_r, Nc)
gridy.x
# Out:
# array([-3.05, -2.95, -2.85, -2.75, -2.65, -2.55, -2.45, -2.35, -2.25,
#        -2.15, -2.05, -1.95, -1.85, -1.75, -1.65, -1.55, -1.45, -1.35,
#        -1.25, -1.15, -1.05, -0.95, -0.85, -0.75, -0.65, -0.55, -0.45,
#        -0.35, -0.25, -0.15, -0.05,  0.05,  0.15,  0.25,  0.35,  0.45,
#         0.55,  0.65,  0.75,  0.85,  0.95,  1.05,  1.15,  1.25,  1.35,
#         1.45,  1.55,  1.65,  1.75,  1.85,  1.95,  2.05,  2.15,  2.25,
#         2.35,  2.45,  2.55,  2.65,  2.75,  2.85,  2.95,  3.05,  3.15,
#         3.25,  3.35,  3.45,  3.55,  3.65,  3.75,  3.85,  3.95,  4.05,
#         4.15,  4.25,  4.35,  4.45,  4.55,  4.65,  4.75,  4.85,  4.95,
#         5.05,  5.15,  5.25,  5.35,  5.45,  5.55,  5.65,  5.75,  5.85,
#         5.95,  6.05,  6.15,  6.25,  6.35,  6.45,  6.55,  6.65,  6.75,
#         6.85,  6.95,  7.05])

# %%
ins_vars = ['velc', 'hvar', 'divv', 'pres']

while scalars.variable['time'] <= scalars.variable['tmax']:
    
    # Compute mass in the domain
    Qin = (simulation.get_qin(gridx, 'velc', bc_type_u['velc']) +
           simulation.get_qin(gridy, 'velc', bc_type_v['velc']))
    
    # Update the outflow boundary velocity using a convective equation.
    simulation.update_outflow_bc(gridx, 'velc', dt)
    
    # Predictor Step
    flowx.ins.advance_euler(gridc, gridx, gridy, scalars, ins_vars, 'predictor')
    
    # Divergence Step
    flowx.ins.advance_euler(gridc, gridx, gridy, scalars, ins_vars, 'divergence')
    
    # Compute mass out of the domain
    Qout = (simulation.get_qout(gridx, 'velc', bc_type_u['velc']) +
            simulation.get_qout(gridy, 'velc', bc_type_v['velc']))
    
    # Rescale velocity at outflow and update BC for corrector step
    simulation.rescale_velocity(gridx, 'velc', bc_type_u['velc'],
                                Qin, Qout) 
    simulation.update_outflow_bc(gridx, 'velc', dt, convvel=0.0)
    
    # Solve the pressure Poisson equation 
    ites, res = flowx.poisson.solve_jacobi(gridc, 'pres', 'divv',
                                         maxiter=2000, tol=1e-9)
    scalars.stats['ites'], scalars.stats['res'] = ites, res
    
    # Corrector Step
    flowx.ins.advance_euler(gridc, gridx, gridy, scalars, ins_vars, 'corrector')
    
    # Display stats
    if scalars.variable['nstep'] % 10 == 0:
        flowx.io.display_stats(scalars)  
        
    if scalars.variable['nstep'] % 100 == 0:
        flowx.io.plot_contour(gridc, 'pres')
        flowx.io.plot_contour(gridx, 'velc')
        flowx.io.plot_vector(gridx,gridy,'velc')
              
    scalars.advance()
# Out:
# ------------ Time = 0.0 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 0.033650919472046535
# Max, Min, U   : 1.0, -1.0
# Max, Min, V   : 0.0, 0.0
# Max, Min, P   : 247.01938571652863, 0.26939022983694544
# Max, Min, DIV : -0.0034058270037962135, -0.2522256219035568
# ------------ Time = 0.09999999999999999 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 0.02502026662568714
# Max, Min, U   : 1.0137866318326432, -1.0
# Max, Min, V   : 0.059906225379807054, -0.059906225379807054
# Max, Min, P   : 559.5303719872619, 540.4659690692912
# Max, Min, DIV : -0.09437530003577516, -0.1056414298598829
#
#
# ------------ Time = 0.20000000000000004 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 0.025000003126266955
# Max, Min, U   : 1.02460451156821, -1.0
# Max, Min, V   : 0.08504075380913234, -0.08504075380913234
# Max, Min, P   : 1050.7162972670837, 1049.315425158135
# Max, Min, DIV : -0.09997711502955808, -0.1000240155671536
#
#
# ------------ Time = 0.3000000000000001 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 0.0250000006694223
# Max, Min, U   : 1.0297513942625809, -1.0
# Max, Min, V   : 0.10365158498060835, -0.10365158498054733
# Max, Min, P   : 1550.1906726643156, 1549.5229408610019
# Max, Min, DIV : -0.09995370093810874, -0.10004601813303673
#
#
# ------------ Time = 0.4000000000000002 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 0.024999999198632893
# Max, Min, U   : 1.0383114143198582, -1.0
# Max, Min, V   : 0.10779898998089282, -0.10779898998078405
# Max, Min, P   : 2050.2665909691323, 2049.4424994370465
# Max, Min, DIV : -0.09999136311812373, -0.1000082915138725
#
#
# ------------ Time = 0.5000000000000002 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 0.024999999312528505
# Max, Min, U   : 1.0471905951553147, -1.0
# Max, Min, V   : 0.1119040230149549, -0.111904023015001
# Max, Min, P   : 2550.279206447725, 2549.4262583886293
# Max, Min, DIV : -0.09999761377257532, -0.10000210458804293
#
#
# ------------ Time = 0.6000000000000003 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 0.024999999452891303
# Max, Min, U   : 1.0528121283709861, -1.0
# Max, Min, V   : 0.11823250622446906, -0.11823250622453084
# Max, Min, P   : 3050.2864654243613, 3049.416170364223
# Max, Min, DIV : -0.09999855703926341, -0.10000121940755516
#
#
# ------------ Time = 0.7000000000000004 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 0.024999999562742035
# Max, Min, U   : 1.054895831134258, -1.0
# Max, Min, V   : 0.12110505515478362, -0.12110505515463471
# Max, Min, P   : 3550.292336142126, 3549.408099397673
# Max, Min, DIV : -0.09999885651279172, -0.10000096491591959
#
#
# ------------ Time = 0.8000000000000005 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 0.024999999647617774
# Max, Min, U   : 1.0575925830864277, -1.0
# Max, Min, V   : 0.12021077515711515, -0.1202107751568978
# Max, Min, P   : 4050.297243809606, 4049.401481356051
# Max, Min, DIV : -0.09999905016426813, -0.10000080595438807
#
#
# ------------ Time = 0.9000000000000006 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 0.024999999713845554
# Max, Min, U   : 1.0582736054732094, -1.0
# Max, Min, V   : 0.11929113167370782, -0.11929113167384767
# Max, Min, P   : 4550.301403223954, 4549.395984210823
# Max, Min, DIV : -0.09999919797034612, -0.10000068522505258
#
#
# ------------ Time = 1.0000000000000007 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 0.024999999766354628
# Max, Min, U   : 1.057469013654475, -1.0
# Max, Min, V   : 0.11889853455977914, -0.11889853455983972
# Max, Min, P   : 5050.304978131291, 5049.391353519525
# Max, Min, DIV : -0.09999931380360705, -0.10000059082726324
# ------------ Time = 1.1000000000000008 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 0.02499999980852233
# Max, Min, U   : 1.0562006723059572, -1.0
# Max, Min, V   : 0.12004885550006308, -0.12004885550021156
# Max, Min, P   : 5550.308092920527, 5549.387402350142
# Max, Min, DIV : -0.09999940569260157, -0.10000051616185592
#
#
# ------------ Time = 1.2000000000000008 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 0.024999999842875556
# Max, Min, U   : 1.055495948638848, -1.0
# Max, Min, V   : 0.12150738858659077, -0.12150738858644802
# Max, Min, P   : 6050.31084183112, 6049.383995997428
# Max, Min, DIV : -0.0999994794328416, -0.10000045645389682
#
#
# ------------ Time = 1.300000000000001 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 0.024999999871254515
# Max, Min, U   : 1.0551794048007854, -1.0
# Max, Min, V   : 0.12256077540369806, -0.12256077540349548
# Max, Min, P   : 6550.31329662031, 6549.381034728809
# Max, Min, DIV : -0.09999953930523475, -0.10000040816914149
#
#
# ------------ Time = 1.400000000000001 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 0.024999999895007036
# Max, Min, U   : 1.0548481776631842, -1.0
# Max, Min, V   : 0.12303815933960596, -0.12303815933980641
# Max, Min, P   : 7050.315512326115, 7049.378440495984
# Max, Min, DIV : -0.099999588505848, -0.10000036867676533
#
#
# ------------ Time = 1.500000000000001 ---------------
# Number of poisson iterations    : 2000
# Final poisson residual : 0.024999999915224332
# Max, Min, U   : 1.0550288639839491, -1.0
# Max, Min, V   : 0.12316924403619764, -0.12316924403604645
# Max, Min, P   : 7550.3175315042345, 7549.376149728535
# Max, Min, DIV : -0.09999962939819285, -0.10000033600541347
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-b2ce19214acf> in <module>
#      27     # Solve the pressure Poisson equation
#      28     ites, res = flowx.poisson.solve_jacobi(gridc, 'pres', 'divv',
# ---> 29                                          maxiter=2000, tol=1e-9)
#      30     scalars.stats['ites'], scalars.stats['res'] = ites, res
#      31
#
# ~/MAE-6225/flowx/poisson/jacobi.py in solve_jacobi(grid, ivar, rvar, maxiter, tol, verbose)
#      48                            (2 * (dx**2 + dy**2)))
#      49
# ---> 50         grid.fill_guard_cells(ivar)
#      51
#      52         residual = (numpy.sqrt(numpy.sum((phi - phi_old)**2) /
#
# ~/MAE-6225/flowx/grid/grid.py in fill_guard_cells(self, var_names)
#     270                                                    bc_types, bc_vals):
#     271                 if bc_type == 'neumann':
# --> 272                     self.fill_guard_cells_neumann(name, loc, bc_val, delta)
#     273                 elif bc_type == 'dirichlet':
#     274                     self.fill_guard_cells_dirichlet(name, loc, bc_val)
#
# KeyboardInterrupt:

# %%
flowx.io.plot_contour(gridc, 'pres')
flowx.io.plot_contour(gridx, 'velc')
flowx.io.plot_vector(gridx,gridy,'velc')

# %%
str(center_vars[1])
# Out:
# 'divv'

# %%
gridx
# Out:
# Grid:
#  - type: <class 'flowx.grid.grid.GridFaceX'>
#  - size: 100 x 50
#  - domain: [-3.0, 7.0] x [-2.5, 2.5]
#  - number of variables: 2

# %%
Nc = 10
Xib, Yib = ibody.ib(ibm_x, ibm_y, ibm_r, Nc) 
theta = numpy.linspace(0.0, 2*numpy.pi, Nc)
x = ibm_x + ibm_r*numpy.cos(theta)
y = ibm_y + ibm_r*numpy.sin(theta)

# %%
from matplotlib import pyplot
type(Xib)
X,Y = numpy.meshgrid(x,y)

# %%
len(x)
# Out:
# 10

# %%
ibody.ib(ibm_x, ibm_y, ibm_r, Nc)
pyplot.scatter(x,y)

# %%
grid.get_values('velc')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-108c48a3b427> in <module>
# ----> 1 grid.get_values('velc')
#
# NameError: name 'grid' is not defined
